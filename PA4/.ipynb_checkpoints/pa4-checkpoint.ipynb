# %% [markdown]
# # Homework 4: Quizlet!
#
# Can you write a program to answer quiz questions?
#
# Do you ever wish you could write a program to take quizzes or tests for you? In this assignment, you’ll do just that! In particular, you’ll leverage word embeddings to write a program that can answer various multiple choice and true/false quiz questions.

# %% [markdown]
# # The Embeddings
# You’ll be using subset of ~4k 50-dimensional GloVe embeddings trained on Wikipedia articles. The GloVe (Global Vectors) model learns vector representations for words by looking at global word-word co-occurrence statistics in a body of text and learning vectors such that their dot product is proportional to the probability of the corresponding words co-occuring in a piece of text. The GloVe model was developed right here at Stanford, and if you’re curious you can read more about it [here](https://nlp.stanford.edu/projects/glove/)!

# %%
# Do not modify this cell, please just run it!
import quizlet

# %% [markdown]
# # Your Mission
# The assignment consists of four parts.

# %% [markdown]
# # Part 1: Synonyms
# For this section, your goal is to answer questions of the form:
#
# ```
#   What is a synonym for warrior?
#   a) soldier
#   b) sailor
#   c) pirate
#   d) spy
# ```
#
# You are given as input a word and a list of candidate choices. Your goal is to return the choice you think is the synonym. You’ll first implement two similarity metrics - euclidean distance and cosine similarity - then leverage them to answer the multiple choice questions!
#
# Specifically, you will implement the following 4 functions:
#
# * **euclidean_distance()**: calculate the euclidean distance between two vectors. Note: you’ll only use this metric in Part 1. For the rest of the assignment, you'll only use cosine similarity.
# * **cosine_similarity()**: calculate the cosine similarity between two vectors. You’ll be using this helper function throughout the other parts of the assignment as well, so you’ll want to get it right!
# * **find_synonym()**: given a word, a list of 4 candidate choices, and which similarity metric to use, return which word you think is the synonym! The function takes in `comparison_metric` as a parameter: if its value is `euc_dist`, you'll use Euclidean distance as the similarity metric; if its value is `cosine_sim`, you'll use cosine similarity as the metric.
# * **part1_written()**: you’ll find that finding synonyms with word embeddings works quite well, especially when using cosine similarity as the metric. However, it’s not perfect. In this function, you’ll look at a question that your `find_synonyms()` function (using cosine similarity) gets wrong, and answer why you think this might be the case. Please return your answer as a string in this function.
#
# Note: for the rest of the assignment, you'll only use cosine similarity as the comparison metric. You won't use the euclidean distance function anymore.

# %%
import numpy as np

def cosine_similarity(v1, v2):
    '''
    Calculates and returns the cosine similarity between vectors v1 and v2
    Arguments:
        v1, v2 (numpy vectors): vectors
    Returns:
        cosine_sim (float): the cosine similarity between v1, v2
    '''
    cosine_sim = 0
    #########################################################
    ## TODO: calculate cosine similarity between v1, v2    ##
    #########################################################
    
    cosine_sim = np.sum(v1*v2)/np.sqrt(np.sum(v1**2)*np.sum(v2**2))

    #########################################################
    ## End TODO                                            ##
    #########################################################
    return cosine_sim   

def euclidean_distance(v1, v2):
    '''
    Calculates and returns the euclidean distance between v1 and v2

    Arguments:
        v1, v2 (numpy vectors): vectors

    Returns:
        euclidean_dist (float): the euclidean distance between v1, v2
    '''
    euclidean_dist = 0
    #########################################################
    ## TODO: calculate euclidean distance between v1, v2   ##
    #########################################################
    
    euclidean_dist = np.sqrt(np.sum((v1 - v2)**2))

    #########################################################
    ## End TODO                                           ##
    #########################################################
    return euclidean_dist                 

def find_synonym(word, choices, embeddings, comparison_metric):
    '''
    Answer a multiple choice synonym question! Namely, given a word w 
    and list of candidate answers, find the word that is most similar to w.
    Similarity will be determined by either euclidean distance or cosine
    similarity, depending on what is passed in as the comparison_metric.

    Arguments:
        word (string): word
        choices (list of strings): list of candidate answers
        embeddings (map): map of words (strings) to their embeddings (np vectors)
        comparison_metric (string): either 'euc_dist' or 'cosine_sim'. 
            This indicates which metric to use - either euclidean distance or cosine similarity.
            With euclidean distance, we want the word with the lowest euclidean distance.
            With cosine similarity, we want the word with the highest cosine similarity.

    Returns:
        answer (string): the word in choices most similar to the given word
    '''
    answer = None
    #########################################################
    ## TODO: find synonym                                  ##
    #########################################################
    
    word_emb = embeddings[word]
    choice_embs = [embeddings[choice] for choice in choices]
    if comparison_metric == 'euc_dist':
        dist = [euclidean_distance(word_emb, choice_emb) for choice_emb in choice_embs]
    elif comparison_metric == 'cosine_sim':
        dist = [-1*cosine_similarity(word_emb, choice_emb) for choice_emb in choice_embs]
    answer = choices[np.argmin(dist)]

    #########################################################
    ## End TODO                                            ##
    ######################################################### 
    return answer

def part1_written():
    '''
    Finding synonyms using cosine similarity on word embeddings does fairly well!
    However, it's not perfect. In particular, you should see that it gets the last
    synonym quiz question wrong (the true answer would be positive):

    30. What is a synonym for sanguine?
        a) pessimistic
        b) unsure
        c) sad
        d) positive

    What word does it choose instead? In 1-2 sentences, explain why you think 
    it got the question wrong.
    '''
    #########################################################
    ## TODO: replace string with your answer               ##
    ######################################################### 
    answer = """
    Maybe because the surroundings of the word sanguine are likely to be negative,
    which makes the embedding of it to 
    """
    #########################################################
    ## End TODO                                            ##
    ######################################################### 
    return answer

# %%
"""This will create a class to test the functions you implemented above. If you are curious, 
you can see the code for this in quizlet.py but it is not required. If you run this cell,
we will load the test data for you and run it on your functions to test your implementation.

You should get an accuracy of 66% with euclidean distance and 83% with cosine distance
"""

part1 = quizlet.Part1_Runner(find_synonym, part1_written)
part1.evaluate(True)  # To only print the scores, pass in False as an argument
# Out:
# Part 1: Synonyms!
# -----------------
# Answering part 1 using euclidean distance as the comparison metric...
# 1. What is a synonym for gullible?
#     a) unrealistic
#     b) naive
#     c) complicated
#     d) wary
# you answered: naive
#
# 2. What is a synonym for counter?
#     a) parry
#     b) agree
#     c) hold
#     d) run
# you answered: hold
#
# 3. What is a synonym for feeble?
#     a) reinforced
#     b) weak
#     c) damage
#     d) break
# you answered: weak
#
# 4. What is a synonym for administer?
#     a) give
#     b) steal
#     c) spray
#     d) box
# you answered: give
#
# 5. What is a synonym for betray?
#     a) trust
#     b) inform
#     c) table
#     d) deceive
# you answered: deceive
#
# 6. What is a synonym for scour?
#     a) search
#     b) allow
#     c) gaze
#     d) gather
# you answered: search
#
# 7. What is a synonym for clean?
#     a) bare
#     b) tidy
#     c) rummage
#     d) pop
# you answered: bare
#
# 8. What is a synonym for abscond?
#     a) escape
#     b) rally
#     c) relinquish
#     d) flash
# you answered: relinquish
#
# 9. What is a synonym for envelop?
#     a) uncover
#     b) dry
#     c) conceal
#     d) surround
# you answered: surround
#
# 10. What is a synonym for curb?
#     a) keep
#     b) find
#     c) limit
#     d) grow
# you answered: limit
#
# 11. What is a synonym for oblivious?
#     a) unaware
#     b) mindful
#     c) precarious
#     d) careful
# you answered: unaware
#
# 12. What is a synonym for corroborate?
#     a) condemn
#     b) grieve
#     c) delight
#     d) confirm
# you answered: confirm
#
# 13. What is a synonym for capricious?
#     a) stable
#     b) unaware
#     c) fickle
#     d) eager
# you answered: fickle
#
# 14. What is a synonym for imminent?
#     a) impending
#     b) possible
#     c) moderate
#     d) unlikely
# you answered: impending
#
# 15. What is a synonym for lucrative?
#     a) honorable
#     b) profitable
#     c) exciting
#     d) predictable
# you answered: profitable
#
# 16. What is a synonym for languish?
#     a) work
#     b) avoid
#     c) attempt
#     d) suffer
# you answered: avoid
#
# 17. What is a synonym for incoherent?
#     a) unclear
#     b) quiet
#     c) wise
#     d) unfeeling
# you answered: unfeeling
#
# 18. What is a synonym for industrious?
#     a) energetic
#     b) prompt
#     c) diligent
#     d) headstrong
# you answered: headstrong
#
# 19. What is a synonym for paucity?
#     a) envy
#     b) greed
#     c) shortage
#     d) presence
# you answered: envy
#
# 20. What is a synonym for ambush?
#     a) surprise
#     b) warn
#     c) treat
#     d) announce
# you answered: surprise
#
# 21. What is a synonym for propose?
#     a) suggest
#     b) doubt
#     c) strive
#     d) write
# you answered: suggest
#
# 22. What is a synonym for vivid?
#     a) bright
#     b) dull
#     c) visible
#     d) loud
# you answered: bright
#
# 23. What is a synonym for keen?
#     a) visible
#     b) omnipotent
#     c) metal
#     d) sharp
# you answered: sharp
#
# 24. What is a synonym for bestow?
#     a) grant
#     b) cost
#     c) wipe
#     d) rise
# you answered: grant
#
# 25. What is a synonym for cogitate?
#     a) mirror
#     b) contemplate
#     c) discuss
#     d) sleep
# you answered: contemplate
#
# 26. What is a synonym for amble?
#     a) escape
#     b) ascend
#     c) groom
#     d) stroll
# you answered: stroll
#
# 27. What is a synonym for trajectory?
#     a) goal
#     b) orbit
#     c) cut
#     d) angle
# you answered: angle
#
# 28. What is a synonym for annex?
#     a) conquer
#     b) limit
#     c) jump
#     d) hide
# you answered: hide
#
# 29. What is a synonym for capitulate?
#     a) defeat
#     b) concede
#     c) raise
#     d) climb
# you answered: concede
#
# 30. What is a synonym for sanguine?
#     a) pessimistic
#     b) unsure
#     c) sad
#     d) positive
# you answered: pessimistic
#
# Answering part 1 using cosine similarity as the comparison metric...
# 1. What is a synonym for gullible?
#     a) unrealistic
#     b) naive
#     c) complicated
#     d) wary
# you answered: naive
#
# 2. What is a synonym for counter?
#     a) parry
#     b) agree
#     c) hold
#     d) run
# you answered: hold
#
# 3. What is a synonym for feeble?
#     a) reinforced
#     b) weak
#     c) damage
#     d) break
# you answered: weak
#
# 4. What is a synonym for administer?
#     a) give
#     b) steal
#     c) spray
#     d) box
# you answered: give
#
# 5. What is a synonym for betray?
#     a) trust
#     b) inform
#     c) table
#     d) deceive
# you answered: deceive
#
# 6. What is a synonym for scour?
#     a) search
#     b) allow
#     c) gaze
#     d) gather
# you answered: search
#
# 7. What is a synonym for clean?
#     a) bare
#     b) tidy
#     c) rummage
#     d) pop
# you answered: bare
#
# 8. What is a synonym for abscond?
#     a) escape
#     b) rally
#     c) relinquish
#     d) flash
# you answered: relinquish
#
# 9. What is a synonym for envelop?
#     a) uncover
#     b) dry
#     c) conceal
#     d) surround
# you answered: surround
#
# 10. What is a synonym for curb?
#     a) keep
#     b) find
#     c) limit
#     d) grow
# you answered: limit
#
# 11. What is a synonym for oblivious?
#     a) unaware
#     b) mindful
#     c) precarious
#     d) careful
# you answered: unaware
#
# 12. What is a synonym for corroborate?
#     a) condemn
#     b) grieve
#     c) delight
#     d) confirm
# you answered: confirm
#
# 13. What is a synonym for capricious?
#     a) stable
#     b) unaware
#     c) fickle
#     d) eager
# you answered: fickle
#
# 14. What is a synonym for imminent?
#     a) impending
#     b) possible
#     c) moderate
#     d) unlikely
# you answered: impending
#
# 15. What is a synonym for lucrative?
#     a) honorable
#     b) profitable
#     c) exciting
#     d) predictable
# you answered: profitable
#
# 16. What is a synonym for languish?
#     a) work
#     b) avoid
#     c) attempt
#     d) suffer
# you answered: suffer
#
# 17. What is a synonym for incoherent?
#     a) unclear
#     b) quiet
#     c) wise
#     d) unfeeling
# you answered: unfeeling
#
# 18. What is a synonym for industrious?
#     a) energetic
#     b) prompt
#     c) diligent
#     d) headstrong
# you answered: diligent
#
# 19. What is a synonym for paucity?
#     a) envy
#     b) greed
#     c) shortage
#     d) presence
# you answered: shortage
#
# 20. What is a synonym for ambush?
#     a) surprise
#     b) warn
#     c) treat
#     d) announce
# you answered: surprise
#
# 21. What is a synonym for propose?
#     a) suggest
#     b) doubt
#     c) strive
#     d) write
# you answered: suggest
#
# 22. What is a synonym for vivid?
#     a) bright
#     b) dull
#     c) visible
#     d) loud
# you answered: bright
#
# 23. What is a synonym for keen?
#     a) visible
#     b) omnipotent
#     c) metal
#     d) sharp
# you answered: sharp
#
# 24. What is a synonym for bestow?
#     a) grant
#     b) cost
#     c) wipe
#     d) rise
# you answered: grant
#
# 25. What is a synonym for cogitate?
#     a) mirror
#     b) contemplate
#     c) discuss
#     d) sleep
# you answered: contemplate
#
# 26. What is a synonym for amble?
#     a) escape
#     b) ascend
#     c) groom
#     d) stroll
# you answered: stroll
#
# 27. What is a synonym for trajectory?
#     a) goal
#     b) orbit
#     c) cut
#     d) angle
# you answered: orbit
#
# 28. What is a synonym for annex?
#     a) conquer
#     b) limit
#     c) jump
#     d) hide
# you answered: conquer
#
# 29. What is a synonym for capitulate?
#     a) defeat
#     b) concede
#     c) raise
#     d) climb
# you answered: concede
#
# 30. What is a synonym for sanguine?
#     a) pessimistic
#     b) unsure
#     c) sad
#     d) positive
# you answered: pessimistic
#
# accuracy using euclidean distance: 0.66667
# accuracy using cosine similarity : 0.83333
# Part 1 written answer contains TODO, did you answer it?
# (0.6666666666666666, 0.8333333333333334)

# %% [markdown]
# # Part 2: Analogies
# For this section, your goal is to answer questions of the form:
#
# ```
#   man is to king as woman is to ___?
#   a) princess
#   b) queen
#   c) wife
#   d) ruler
# ```
#
# Namely, you are trying to find the word bb that completes the analogy a:b → aa:bb. You will take as input three words, a, b, aa, and a list of candidate choices and return the choice you think completes the analogy.
#
# One of the neat properties of embeddings is their ability to capture relational meanings. In fact, for the analogy **man:king → woman:queen** above, we have that the vector:
#
# `vector('king') - vector('man') + vector('woman')`
#
# is a vector close to  `vector('queen')`. Make sure that when completing these analogies, you are following the **same logical order** as the example above in order to align with our test set. You’ll leverage this pattern to try to answer the quizlet questions!
#
# Specifically, you will implement the following function:
#
# * **find_analogy_word()**: given a, b, and aa, find the best word in a list of candidate choices that completes the analogy (leveraging cosine similarity as your similarity metric).

# %%
def find_analogy_word(a, b, aa, choices, embeddings):
    '''
    Find the word bb that completes the analogy: a:b -> aa:bb
    A classic example would be: man:king -> woman:queen

    Note: use cosine similarity as your similarity metric

    Arguments:
        a, b, aa (strings): words in the analogy described above
        choices (list): list of strings for possible answer
        embeddings (map): map of words (strings) to their embeddings (np vectors)

    Returns:
        answer: the word bb that completes the analogy
    '''
    answer = None
    #########################################################
    ## TODO: analogy                                       ##
    #########################################################
    
    emb_a, emb_b, emb_aa = embeddings[a], embeddings[b], embeddings[aa]
    emb_bb = (emb_b - emb_a) + emb_aa
    choice_embs = [embeddings[choice] for choice in choices]
    choice_scores = [cosine_similarity(emb_bb, choice_emb) for choice_emb in choice_embs]
    answer = choices[np.argmax(choice_scores)]

    #########################################################
    ## End TODO                                            ##
    #########################################################
    return answer

# %%
# You should get an accuracy of 64%

part2 = quizlet.Part2_Runner(find_analogy_word)
part2.evaluate(True) # To only print the scores, pass in False as an argument
# Out:
# Part 2: Analogies!
# ------------------
# 1. king is to queen as man is to ___?
#     a) wife
#     b) woman
#     c) head
#     d) ruler
# You answered: woman
#
# 2. dog is to puppy as cat is to ___?
#     a) kitten
#     b) puppy
#     c) feline
#     d) mouse
# You answered: puppy
#
# 3. father is to son as mother is to ___?
#     a) girl
#     b) wife
#     c) daughter
#     d) queen
# You answered: daughter
#
# 4. listen is to hear as look is to ___?
#     a) taste
#     b) see
#     c) feel
#     d) think
# You answered: think
#
# 5. doctor is to hospital as lawyer is to ___?
#     a) court
#     b) restaurant
#     c) museum
#     d) library
# You answered: court
#
# 6. good is to great as bad is to ___?
#     a) better
#     b) worse
#     c) okay
#     d) sad
# You answered: worse
#
# 7. stove is to kitchen as tub is to ___?
#     a) closet
#     b) bedroom
#     c) bathroom
#     d) pantry
# You answered: bathroom
#
# 8. spoon is to soup as fork is to ___?
#     a) sorbet
#     b) steak
#     c) banana
#     d) berry
# You answered: steak
#
# 9. phone is to talk as television is to ___?
#     a) hear
#     b) watch
#     c) sleep
#     d) read
# You answered: watch
#
# 10. carrot is to orange as banana is to ___?
#     a) green
#     b) yellow
#     c) red
#     d) black
# You answered: black
#
# 11. sleep is to bed as sit is to ___?
#     a) dresser
#     b) closet
#     c) chair
#     d) desk
# You answered: closet
#
# 12. rock is to hard as feather is to ___?
#     a) flat
#     b) limp
#     c) rough
#     d) soft
# You answered: soft
#
# 13. bowl is to soup as plate is to ___?
#     a) sandwich
#     b) banana
#     c) yogurt
#     d) jam
# You answered: sandwich
#
# 14. bird is to eagle as snake is to ___?
#     a) reptile
#     b) cobra
#     c) poison
#     d) skin
# You answered: cobra
#
# 15. attach is to join as surrender is to ___?
#     a) forfeit
#     b) explain
#     c) frighten
#     d) risk
# You answered: forfeit
#
# 16. heat is to cold as tranquility is to ___?
#     a) government
#     b) control
#     c) island
#     d) commotion
# You answered: island
#
# 17. wet is to dry as dull is to ___?
#     a) dreary
#     b) unfailing
#     c) spirited
#     d) long
# You answered: spirited
#
# 18. meat is to carnivore as plant is to ___?
#     a) omnivore
#     b) herbivore
#     c) canine
#     d) human
# You answered: herbivore
#
# 19. zebra is to animal as dessert is to ___?
#     a) color
#     b) shape
#     c) food
#     d) country
# You answered: food
#
# 20. hideous is to pretty as nice is to ___?
#     a) kind
#     b) safe
#     c) terrible
#     d) mean
# You answered: kind
#
# 21. one is to single as two is to ___?
#     a) triple
#     b) double
#     c) multiple
#     d) three
# You answered: double
#
# 22. fox is to foxes as goose is to ___?
#     a) cow
#     b) duck
#     c) geese
#     d) birds
# You answered: geese
#
# 23. seed is to plant as egg is to ___?
#     a) mouse
#     b) tree
#     c) bird
#     d) oyster
# You answered: oyster
#
# 24. scissor is to cut as needle is to ___?
#     a) point
#     b) stab
#     c) sew
#     d) repair
# You answered: point
#
# 25. hungry is to full as good is to ___?
#     a) kind
#     b) evil
#     c) lovely
#     d) neutral
# You answered: kind
#
# accuracy: 0.64000
# 0.64

# %% [markdown]
# # Part 3: Sentence Similarity
# For this section, your goal is to answer questions of the form:
#
# ```
#     True/False: the following two sentences are semantically similar:
#       1. he later learned that the incident was caused by the concorde's sonic boom
#       2. he later found out the alarming incident had been caused by concorde's powerful sonic boom
# ```
#
# Namely, you take in 2 sentences as input, and output either true or false (ie, a label of 1 or 0). To do this, you will create a sentence embedding that represents each sentence in vector form, then apply cosine similarity to compute the similarity between the two sentence embeddings. If they have a high enough similarity, you’ll guess "True" and otherwise "False".
#
# To accomplish this, you’ll first turn each sentence into a single vector embedding. There are a few different ways you can do this. For this assignment, we’ll look at two approaches:
#
# * **Simple sum**: Sum the word embeddings of each individual word in the sentence. This resulting vector is the sentence embedding vector.
# * **Sum with POS weighting**: Take a weighted sum of the individual word vectors, where the weighting depends on the part of speech (POS) of that given word. Each POS (ie, verb, noun, adjective, etc) has a different scalar weight associated with it. We multiply each word vector by the scalar weight associated with its part of speech, then sum these weighted vectors.
#
# Specifically, you will implement the following 2 functions:
#
# * **get_embedding()**: given a sentence (string), return the sentence embedding (vector). The function also takes in the parameter `use_POS`:
#     * if `use_POS` is false (regular case), leverage method 1 above - simply the sum of the word embeddings for each word in the sentence (ignoring words that don’t appear in our vocabulary).
#     * if `use_POS` is true, leverage method 2 - use a weighted sum, where we weight each word by a scalar that depends on its part of speech tag.
# * **get_similarity()**: given two sentences, find the cosine similarity between their corresponding sentence embeddings.
#
# Helpful hints:
#
# * We’ve given you a map `POS_weights` that maps part of speech tags to their associated weight. For example, `POS_weights['NN'] = 0.8` (where NN is the POS tag for noun).
# * You may skip words that either (1) are not in our embeddings or (2) have a POS tag that is not in `POS_weights` .
# * To get a list of all the words in the sentence, use nltk's word_tokenize function.
#
#   ```
#   >>> sentence = "this is a sentence"
#   >>> word_tokens = word_tokenize(sentence)
#   >>> word_tokens
#   ['this', 'is', 'a', 'sentence']
#   ```
#
# * To get the POS tags for each word in a sentence, you can use nltk.pos_tag. To use it, you provide a list of words in a sentence, and it returns a list of tuples, where the first element is the word and the second is its corresponding POS tag. **For this PA, make sure that you pass in the entire sentence to a single call to nltk.pos_tag; do not call  nltk.pos_tag separately on each word in the sentence.** This is because some words can be multiple parts of speech (for example, "back" can be a noun or a verb). Passing in the entire sentence allows for more context to figure out what POS tag a word should have.
#
# ```
#     >>> tagged_words = nltk.pos_tag(word_tokens)
#     >>> tagged_words
#     [('this', 'DT'), ('is', 'VBZ'), ('a', 'DT'), ('sentence', 'NN')]`
# ```

# %%
# You will use nltk for tokenizing and tagging!
import nltk
from nltk.tokenize import word_tokenize

# %%
# Run this cell to download the nltk tagger
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /home/pchen/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/pchen/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
def get_embedding(s, embeddings, use_POS=False, POS_weights=None):
    '''
    Returns vector embedding for a given sentence.

    Hint:
    - to get all the words in the sentence, you can use nltk's `word_tokenize` function
        >>> list_of_words = word_tokenize(sentence_string)
    - to get part of speech tags for words in a sentence, you can use `nltk.pos_tag`
        >>> tagged_tokens = nltk.pos_tag(list_of_words)
    - you can read more here: https://www.nltk.org/book/ch05.html

    Arguments:
        s (string): sentence
        embeddings (map): map of words (strings) to their embeddings (np vectors)
        use_POS (boolean): flag indicating whether to use POS weightings when
            calculating the sentence embedding
        POS_weights (map): map of part of speech tags (strings) to their weights (floats),
            it is only to be used if the use_POS flag is true

    Returns:
        embed (np vector): vector embedding of sentence s
    '''
    embed = np.zeros(embeddings.vector_size)
    #########################################################
    ## TODO: get embedding                                 ##
    #########################################################
    
    list_of_words = word_tokenize(s)
    if use_POS:
        tagged_tokens = nltk.pos_tag(list_of_words)
        word_embs = np.array([POS_weights[tag]*embeddings[w] for w, tag in tagged_tokens \
                              if w in embeddings and tag in POS_weights])
    else:
        word_embs = np.array([embeddings[w] for w in list_of_words if w in embeddings])
    embed = word_embs.sum(axis=0)

    #########################################################
    ## End TODO                                            ##
    #########################################################
    return embed

def get_similarity(s1, s2, embeddings, use_POS, POS_weights=None):
    '''
    Given 2 sentences and the embeddings dictionary, convert the sentences
    into sentence embeddings and return the cosine similarity between them.

    Arguments:
        s1, s2 (strings): sentences
        embeddings (map): map of words (strings) to their embeddings (np vectors)
        use_POS (boolean): flag indicating whether to use POS weightings when
            calculating the sentence embedding
        POS_weights (map): map of part of speech tags (strings) to their weights (floats),
            it is only to be used if the use_POS flag is true

    Returns:
        similarity (float): cosine similarity of the two sentence embeddings
    '''
    similarity = 0
    #########################################################
    ## TODO: compute similarity                            ##
    #########################################################
    
    s1_emb = get_embedding(s1, embeddings, use_POS, POS_weights)
    s2_emb = get_embedding(s2, embeddings, use_POS, POS_weights)
    similarity = cosine_similarity(s1_emb, s2_emb)

    #########################################################
    ## End TODO                                            ##
    #########################################################
    return similarity

# %%
# You should get an accuracy of 78% without POS weights, and 88% with.

part3 = quizlet.Part3_Runner(get_similarity)
part3.evaluate(True) # To only print the scores, pass in False as an argument
# Out:
# Part 3: Sentence similarity!
# ----------------------------
# Answering part 3 (regular)...
# 1. True/False: the following two sentences are semantically similar:
#      1. one woman is measuring another woman's ankle.
#      2. a woman measures another woman's ankle.
# You answered: True
#
# 2. True/False: the following two sentences are semantically similar:
#      1. a man is cutting an onion.
#      2. a man cuts an onion.
# You answered: True
#
# 3. True/False: the following two sentences are semantically similar:
#      1. a young woman is putting stickers all over her face.
#      2. a woman is applying stickers to her face.
# You answered: True
#
# 4. True/False: the following two sentences are semantically similar:
#      1. a woman is dancing in the rain.
#      2. a woman dances in the rain out side.
# You answered: True
#
# 5. True/False: the following two sentences are semantically similar:
#      1. the man is kissing and hugging the woman.
#      2. a man is hugging and kissing a woman.
# You answered: True
#
# 6. True/False: the following two sentences are semantically similar:
#      1. a man is playing the guitar and singing.
#      2. a man sings with a guitar.
# You answered: True
#
# 7. True/False: the following two sentences are semantically similar:
#      1. a man is doing trick with play cards.
#      2. a man is performing a card trick.
# You answered: True
#
# 8. True/False: the following two sentences are semantically similar:
#      1. the lady peeled the potatoe.
#      2. a woman is peeling a potato.
# You answered: False
#
# 9. True/False: the following two sentences are semantically similar:
#      1. a woman and man are dancing in the rain.
#      2. a man and woman are dancing in rain.
# You answered: True
#
# 10. True/False: the following two sentences are semantically similar:
#      1. two men are fistfighting in a ring.
#      2. two men fistfight in a ring.
# You answered: True
#
# 11. True/False: the following two sentences are semantically similar:
#      1. a woman is stabbing a potato with a fork.
#      2. a woman is puncturing a potato with a fork.
# You answered: True
#
# 12. True/False: the following two sentences are semantically similar:
#      1. a boy is playing a key-board.
#      2. a little boy is playing a keyboard.
# You answered: True
#
# 13. True/False: the following two sentences are semantically similar:
#      1. a woman plays the flute.
#      2. a woman is playing the flute.
# You answered: True
#
# 14. True/False: the following two sentences are semantically similar:
#      1. a group of people are sweeping water out of a house.
#      2. people are sweeping water out of a house.
# You answered: True
#
# 15. True/False: the following two sentences are semantically similar:
#      1. a man plays a guitar.
#      2. a man is playing a guitar.
# You answered: True
#
# 16. True/False: the following two sentences are semantically similar:
#      1. a man is playing a musical keyboard.
#      2. a man is playing a keyboard piano.
# You answered: True
#
# 17. True/False: the following two sentences are semantically similar:
#      1. a man plays a trumpet.
#      2. a man is playing the trumpet.
# You answered: True
#
# 18. True/False: the following two sentences are semantically similar:
#      1. the man is eating.
#      2. a man is eating food.
# You answered: True
#
# 19. True/False: the following two sentences are semantically similar:
#      1. a person is slicing onions.
#      2. someone is slicing an onion.
# You answered: True
#
# 20. True/False: the following two sentences are semantically similar:
#      1. two dogs and one cat sitting on couch.
#      2. two dogs and a cat resting on a couch.
# You answered: True
#
# 21. True/False: the following two sentences are semantically similar:
#      1. two green and white trains sitting on the tracks.
#      2. two green and white trains are sitting on the train track.
# You answered: True
#
# 22. True/False: the following two sentences are semantically similar:
#      1. a man in a top hat rides a white horse.
#      2. a man with a top hat riding a white horse.
# You answered: True
#
# 23. True/False: the following two sentences are semantically similar:
#      1. blue and red plane in mid-air flight.
#      2. a blue and red airplane while in flight.
# You answered: True
#
# 24. True/False: the following two sentences are semantically similar:
#      1. a group of horses grazing in a field.
#      2. group of horses grazing in grassy field.
# You answered: True
#
# 25. True/False: the following two sentences are semantically similar:
#      1. three goats are being rounded up by a dog.
#      2. three goats are chased by a dog.
# You answered: True
#
# 26. True/False: the following two sentences are semantically similar:
#      1. train in a station.
#      2. a train in a station.
# You answered: True
#
# 27. True/False: the following two sentences are semantically similar:
#      1. a blue bird standing on a lawn.
#      2. blue bird standing on green grass.
# You answered: True
#
# 28. True/False: the following two sentences are semantically similar:
#      1. a green car parked at a saloon.
#      2. a green car parked outside the saloon.
# You answered: True
#
# 29. True/False: the following two sentences are semantically similar:
#      1. group of people sitting around a restaurant dining table.
#      2. a group of people sitting at a restaurant table.
# You answered: True
#
# 30. True/False: the following two sentences are semantically similar:
#      1. a philips flat-screen tv is shown with its two remote controls.
#      2. a phillips flat screen tv with two remote controls.
# You answered: True
#
# 31. True/False: the following two sentences are semantically similar:
#      1. the train sits at the train station.
#      2. a train parked at a train station.
# You answered: True
#
# 32. True/False: the following two sentences are semantically similar:
#      1. three people sit at a picnic table outside of a building painted like a union jack.
#      2. three people sit at an outdoor table in front of a building painted like the union jack.
# You answered: True
#
# 33. True/False: the following two sentences are semantically similar:
#      1. a bird flies across the water.
#      2. a bird flies above the water.
# You answered: True
#
# 34. True/False: the following two sentences are semantically similar:
#      1. the dog is running through a field.
#      2. a dog runs through a field.
# You answered: True
#
# 35. True/False: the following two sentences are semantically similar:
#      1. two boys playing a game of flag football.
#      2. two boys are playing flag football.
# You answered: True
#
# 36. True/False: the following two sentences are semantically similar:
#      1. one white boy and one black boy stand with arms around each other.
#      2. two young boys, one white and one black, are standing with their arms around each other.
# You answered: True
#
# 37. True/False: the following two sentences are semantically similar:
#      1. the two dogs are playing in the yard.
#      2. two dogs are playing on the grass.
# You answered: True
#
# 38. True/False: the following two sentences are semantically similar:
#      1. four children are playing on a trampoline.
#      2. four kids are jumping on a trampoline.
# You answered: True
#
# 39. True/False: the following two sentences are semantically similar:
#      1. a black dog running into the water.
#      2. a black dog running through water.
# You answered: True
#
# 40. True/False: the following two sentences are semantically similar:
#      1. a dog jumps into the water.
#      2. a dog is jumping into the water.
# You answered: True
#
# 41. True/False: the following two sentences are semantically similar:
#      1. a man and a dog on rocks on a beach.
#      2. a man and dog on a rocky seashore.
# You answered: True
#
# 42. True/False: the following two sentences are semantically similar:
#      1. two dogs are running in the field.
#      2. two dogs running in a field.
# You answered: True
#
# 43. True/False: the following two sentences are semantically similar:
#      1. two brown dogs runs through the water.
#      2. two brown dogs running through water.
# You answered: True
#
# 44. True/False: the following two sentences are semantically similar:
#      1. a man climbing a rock-face.
#      2. a man is climbing a rock wall.
# You answered: True
#
# 45. True/False: the following two sentences are semantically similar:
#      1. the surfer does a flip off of a wave.
#      2. a surfer does a flip on a wave.
# You answered: True
#
# 46. True/False: the following two sentences are semantically similar:
#      1. a blonde haired toddler swinging on a tire swing.
#      2. a blonde haired child is swinging on a tire swing.
# You answered: True
#
# 47. True/False: the following two sentences are semantically similar:
#      1. one boy is pushing another boy on a swing.
#      2. a boy is pushing another boy on the swings.
# You answered: True
#
# 48. True/False: the following two sentences are semantically similar:
#      1. two black dogs are playing on the grass.
#      2. two black dogs are playing in a grassy plain.
# You answered: True
#
# 49. True/False: the following two sentences are semantically similar:
#      1. a man in a black suit is surfing along a crashing wave.
#      2. a surfer wearing a black wet suit is riding a a white wave in the ocean.
# You answered: True
#
# 50. True/False: the following two sentences are semantically similar:
#      1. a man running on a track.
#      2. a man running track
# You answered: True
#
# 51. True/False: the following two sentences are semantically similar:
#      1. a man steers a blue boat past brightly colored houses.
#      2. a man driving a blue boat passes by some colorful houses.
# You answered: True
#
# 52. True/False: the following two sentences are semantically similar:
#      1. a deer jumps a fence.
#      2. a deer is jumping over a fence.
# You answered: True
#
# 53. True/False: the following two sentences are semantically similar:
#      1. a young person  deep in thought.
#      2. a young man deep in thought.
# You answered: True
#
# 54. True/False: the following two sentences are semantically similar:
#      1. some guy sitting on a couch watching television.
#      2. a guy is sitting on the couch watching tv
# You answered: True
#
# 55. True/False: the following two sentences are semantically similar:
#      1. there is a cook preparing food.
#      2. a cook is making food.
# You answered: True
#
# 56. True/False: the following two sentences are semantically similar:
#      1. people gathered in a room.
#      2. people gathered together in a room.
# You answered: True
#
# 57. True/False: the following two sentences are semantically similar:
#      1. people getting their dirty clothes cleaned
#      2. people are getting their clothes cleaned.
# You answered: True
#
# 58. True/False: the following two sentences are semantically similar:
#      1. a man is laughing with a woman
#      2. a man and a woman laughing.
# You answered: True
#
# 59. True/False: the following two sentences are semantically similar:
#      1. the people are running a marathon
#      2. people are running a marathon
# You answered: True
#
# 60. True/False: the following two sentences are semantically similar:
#      1. a brown dog is jumping.
#      2. a brown dog is jumping
# You answered: True
#
# 61. True/False: the following two sentences are semantically similar:
#      1. you do not need to worry.
#      2. you don't have to worry.
# You answered: True
#
# 62. True/False: the following two sentences are semantically similar:
#      1. you can do it, too.
#      2. yes, you can do it.
# You answered: True
#
# 63. True/False: the following two sentences are semantically similar:
#      1. the answer to both questions is: yes.
#      2. the answer to both of your questions is yes.
# You answered: True
#
# 64. True/False: the following two sentences are semantically similar:
#      1. you guys are making this all waaaaay too complicated.
#      2. you are making this too complicated.
# You answered: True
#
# 65. True/False: the following two sentences are semantically similar:
#      1. it's not a good idea.
#      2. it is not a good idea.
# You answered: True
#
# 66. True/False: the following two sentences are semantically similar:
#      1. take a look at these:
#      2. take a look at this:
# You answered: True
#
# 67. True/False: the following two sentences are semantically similar:
#      1. this is not a good idea.
#      2. but it is not a good idea.
# You answered: True
#
# 68. True/False: the following two sentences are semantically similar:
#      1. i was in a similar situation.
#      2. i had a similar situation.
# You answered: True
#
# 69. True/False: the following two sentences are semantically similar:
#      1. i've had this same problem.
#      2. i had this same problem.
# You answered: True
#
# 70. True/False: the following two sentences are semantically similar:
#      1. you answered your own question.
#      2. you have answered your own question.
# You answered: True
#
# 71. True/False: the following two sentences are semantically similar:
#      1. i don't see why there should be any problem with this whatsoever.
#      2. i don't see why that should be a problem.
# You answered: True
#
# 72. True/False: the following two sentences are semantically similar:
#      1. it makes absolutely no difference.
#      2. no, it makes no difference.
# You answered: True
#
# 73. True/False: the following two sentences are semantically similar:
#      1. i think it's fine to ask this question.
#      2. i think it is okay to ask the question.
# You answered: True
#
# 74. True/False: the following two sentences are semantically similar:
#      1. there's not a lot you can do about that.
#      2. i'm afraid there's not really a lot you can do.
# You answered: True
#
# 75. True/False: the following two sentences are semantically similar:
#      1. you answered your own question.
#      2. you've answered your own question already.
# You answered: True
#
# 76. True/False: the following two sentences are semantically similar:
#      1. can you do this?
#      2. can you do it?
# You answered: True
#
# 77. True/False: the following two sentences are semantically similar:
#      1. how do you do that?
#      2. how to do that?
# You answered: True
#
# 78. True/False: the following two sentences are semantically similar:
#      1. it's also a matter of taste.
#      2. it's definitely just a matter of preference.
# You answered: True
#
# 79. True/False: the following two sentences are semantically similar:
#      1. i don't see why there should be any problem with this whatsoever.
#      2. i don't see why this could be a problem.
# You answered: True
#
# 80. True/False: the following two sentences are semantically similar:
#      1. there's not a lot you can do about that.
#      2. i really do not think there is much you can do about that.
# You answered: True
#
# 81. True/False: the following two sentences are semantically similar:
#      1. you got it right.
#      2. yes you got it.
# You answered: True
#
# 82. True/False: the following two sentences are semantically similar:
#      1. there are two things to consider:
#      2. a couple things to consider:
# You answered: True
#
# 83. True/False: the following two sentences are semantically similar:
#      1. can you do this?
#      2. so, can you do this?
# You answered: True
#
# 84. True/False: the following two sentences are semantically similar:
#      1. there are a few things you can do:
#      2. there are a couple things you can try.
# You answered: True
#
# 85. True/False: the following two sentences are semantically similar:
#      1. you got it right.
#      2. you've got it right.
# You answered: True
#
# 86. True/False: the following two sentences are semantically similar:
#      1. you answered your own question.
#      2. you pretty much answered your own question.
# You answered: True
#
# 87. True/False: the following two sentences are semantically similar:
#      1. you are on the right path.
#      2. you're on the right path.
# You answered: True
#
# 88. True/False: the following two sentences are semantically similar:
#      1. what are your goals?
#      2. what are you goals?
# You answered: True
#
# 89. True/False: the following two sentences are semantically similar:
#      1. a few more point to think about:
#      2. a few things to think about:
# You answered: True
#
# 90. True/False: the following two sentences are semantically similar:
#      1. i'm afraid we are out of luck in this one.
#      2. i think this is one of those things where you are just out of luck.
# You answered: True
#
# 91. True/False: the following two sentences are semantically similar:
#      1. it's also a matter of taste.
#      2. it's mostly a matter of taste.
# You answered: True
#
# 92. True/False: the following two sentences are semantically similar:
#      1. i had the same problem as you.
#      2. i have just had the same problem.
# You answered: True
#
# 93. True/False: the following two sentences are semantically similar:
#      1. i'm thinking it's a bad idea.
#      2. i think it's a bad idea.
# You answered: True
#
# 94. True/False: the following two sentences are semantically similar:
#      1. it's not a good idea.
#      2. not a good idea.
# You answered: True
#
# 95. True/False: the following two sentences are semantically similar:
#      1. i had the same problem as you.
#      2. i have exactly the same problem.
# You answered: True
#
# 96. True/False: the following two sentences are semantically similar:
#      1. there are two things to consider:
#      2. i think there are two important things to consider:
# You answered: True
#
# 97. True/False: the following two sentences are semantically similar:
#      1. it's pretty much up to you.
#      2. it is up to you.
# You answered: True
#
# 98. True/False: the following two sentences are semantically similar:
#      1. there are three options:
#      2. there are only three options:
# You answered: True
#
# 99. True/False: the following two sentences are semantically similar:
#      1. so think it in this way.
#      2. think of it this way.
# You answered: True
#
# 100. True/False: the following two sentences are semantically similar:
#      1. maybe this could work for you.
#      2. maybe this can work for you.
# You answered: True
#
# 101. True/False: the following two sentences are semantically similar:
#      1. the woman is styling her hair.
#      2. the woman is slicing herbs.
# You answered: True
#
# 102. True/False: the following two sentences are semantically similar:
#      1. a man is kicking pots of water.
#      2. a man is picking flowers.
# You answered: True
#
# 103. True/False: the following two sentences are semantically similar:
#      1. a man is playing a guitar.
#      2. a man is driving a car.
# You answered: False
#
# 104. True/False: the following two sentences are semantically similar:
#      1. a woman is dancing.
#      2. a woman is playing violin.
# You answered: True
#
# 105. True/False: the following two sentences are semantically similar:
#      1. a woman is water skiing.
#      2. a woman is slicing fish.
# You answered: True
#
# 106. True/False: the following two sentences are semantically similar:
#      1. a woman is picking a can.
#      2. a man is playing a guitar.
# You answered: True
#
# 107. True/False: the following two sentences are semantically similar:
#      1. a woman is cutting an onion.
#      2. a woman is cleaning a garden.
# You answered: True
#
# 108. True/False: the following two sentences are semantically similar:
#      1. a train is moving.
#      2. a man is doing yoga.
# You answered: False
#
# 109. True/False: the following two sentences are semantically similar:
#      1. a man is holding a leaf.
#      2. a monkey is fighting a man.
# You answered: True
#
# 110. True/False: the following two sentences are semantically similar:
#      1. a woman is peeling shrimp.
#      2. a man is squeezing water.
# You answered: False
#
# 111. True/False: the following two sentences are semantically similar:
#      1. a man is playing a guitar.
#      2. a woman is riding a horse.
# You answered: False
#
# 112. True/False: the following two sentences are semantically similar:
#      1. a woman opens a window.
#      2. a man is crawling.
# You answered: False
#
# 113. True/False: the following two sentences are semantically similar:
#      1. a woman is filing her nails.
#      2. a man is peeling a carrot.
# You answered: False
#
# 114. True/False: the following two sentences are semantically similar:
#      1. a woman is swimming underwater.
#      2. a man is slicing some carrots.
# You answered: False
#
# 115. True/False: the following two sentences are semantically similar:
#      1. a man is opening a box and taking out paper.
#      2. a woman is peeling a potato.
# You answered: False
#
# 116. True/False: the following two sentences are semantically similar:
#      1. a woman is cracking eggs.
#      2. a man is talking to a woman.
# You answered: True
#
# 117. True/False: the following two sentences are semantically similar:
#      1. a cat is walking around a house.
#      2. a woman is peeling potato.
# You answered: False
#
# 118. True/False: the following two sentences are semantically similar:
#      1. a woman is talking to her pet bunny as she fondles it.
#      2. a woman walks her dog onto astro turf.
# You answered: False
#
# 119. True/False: the following two sentences are semantically similar:
#      1. a man is playing guitar.
#      2. a boy is talking to a giant dog.
# You answered: False
#
# 120. True/False: the following two sentences are semantically similar:
#      1. a cat is playing on the floor.
#      2. a man is slicing garlic.
# You answered: True
#
# 121. True/False: the following two sentences are semantically similar:
#      1. a boy is playing violin on stage.
#      2. a person is mixing a pot.
# You answered: False
#
# 122. True/False: the following two sentences are semantically similar:
#      1. a woman is slicing ginger.
#      2. a person is holding two baby lorises.
# You answered: True
#
# 123. True/False: the following two sentences are semantically similar:
#      1. a woman is spreading mustard on a bread roll.
#      2. a kitten is playing with a woman's finger.
# You answered: False
#
# 124. True/False: the following two sentences are semantically similar:
#      1. someone touched the kitten chewing on a string.
#      2. someone is cutting paper.
# You answered: False
#
# 125. True/False: the following two sentences are semantically similar:
#      1. meat is being put into a skillet.
#      2. a woman is putting a baby into a trash can.
# You answered: True
#
# 126. True/False: the following two sentences are semantically similar:
#      1. a baby elephant is eating a small tree.
#      2. a little girl peddling a scooter.
# You answered: False
#
# 127. True/False: the following two sentences are semantically similar:
#      1. someone is drawing.
#      2. someone is dancing.
# You answered: True
#
# 128. True/False: the following two sentences are semantically similar:
#      1. a person is playing a piano.
#      2. a person is slicing a potato.
# You answered: False
#
# 129. True/False: the following two sentences are semantically similar:
#      1. a man is dancing.
#      2. a woman is exercising.
# You answered: True
#
# 130. True/False: the following two sentences are semantically similar:
#      1. a woman is exercising.
#      2. a man is dancing.
# You answered: True
#
# 131. True/False: the following two sentences are semantically similar:
#      1. a man is doing exercise.
#      2. a man is firing a rifle.
# You answered: True
#
# 132. True/False: the following two sentences are semantically similar:
#      1. a man is playing a piano.
#      2. a guy is peeling a potato.
# You answered: False
#
# 133. True/False: the following two sentences are semantically similar:
#      1. a man is bowling.
#      2. a kitten is walking.
# You answered: True
#
# 134. True/False: the following two sentences are semantically similar:
#      1. a woman is dancing near a fire.
#      2. a woman is cutting a tomatoe.
# You answered: True
#
# 135. True/False: the following two sentences are semantically similar:
#      1. a person is riding a motorcyle.
#      2. a person is chopping an onion.
# You answered: False
#
# 136. True/False: the following two sentences are semantically similar:
#      1. a man is talking on the phone.
#      2. a man is moon-walking across a store.
# You answered: True
#
# 137. True/False: the following two sentences are semantically similar:
#      1. a woman is braiding her hair.
#      2. a man is riding a motorcycle.
# You answered: False
#
# 138. True/False: the following two sentences are semantically similar:
#      1. the woman is slicing tofu.
#      2. the woman is putting on lipstick.
# You answered: True
#
# 139. True/False: the following two sentences are semantically similar:
#      1. a woman is folding paper.
#      2. a woman is applying eye shadow.
# You answered: True
#
# 140. True/False: the following two sentences are semantically similar:
#      1. someone is folding a piece of paper.
#      2. a person is slicing a small pieces of ginger.
# You answered: True
#
# 141. True/False: the following two sentences are semantically similar:
#      1. a man is lifting weights.
#      2. a man is chopping egg plant.
# You answered: False
#
# 142. True/False: the following two sentences are semantically similar:
#      1. a man is playing a cello.
#      2. a man is rapidly lifting small weights.
# You answered: False
#
# 143. True/False: the following two sentences are semantically similar:
#      1. the man is talking.
#      2. a man is walking down stairs.
# You answered: True
#
# 144. True/False: the following two sentences are semantically similar:
#      1. a man is playing the drums.
#      2. a woman is slicing some leaves.
# You answered: True
#
# 145. True/False: the following two sentences are semantically similar:
#      1. a man is hitting a boy with flower vase.
#      2. a man is cutting a mat.
# You answered: True
#
# 146. True/False: the following two sentences are semantically similar:
#      1. the man is mixing whipping cream.
#      2. the man is holding a skunk.
# You answered: False
#
# 147. True/False: the following two sentences are semantically similar:
#      1. a man is singing while playing the guitar.
#      2. a man is stuffing himself full with food.
# You answered: False
#
# 148. True/False: the following two sentences are semantically similar:
#      1. a boat sails along the water.
#      2. the man is playing the guitar.
# You answered: False
#
# 149. True/False: the following two sentences are semantically similar:
#      1. an okapi is eating from a tree.
#      2. a moose drinks from a sprinkler.
# You answered: True
#
# 150. True/False: the following two sentences are semantically similar:
#      1. a woman is pouring egg into a frying pan.
#      2. a man is petting two dogs.
# You answered: False
#
# 151. True/False: the following two sentences are semantically similar:
#      1. a woman is frying ground meat.
#      2. a man is cutting a trunk with an axe.
# You answered: False
#
# 152. True/False: the following two sentences are semantically similar:
#      1. a person is boiling noodles.
#      2. a cat is licking a bottle.
# You answered: False
#
# 153. True/False: the following two sentences are semantically similar:
#      1. a man reels in a fish.
#      2. a woman is pouring oil in a bowl.
# You answered: True
#
# 154. True/False: the following two sentences are semantically similar:
#      1. a woman is cutting an onion.
#      2. a horse is standing.
# You answered: False
#
# 155. True/False: the following two sentences are semantically similar:
#      1. a person is adding food in a pan.
#      2. a man is dancing in the street.
# You answered: False
#
# 156. True/False: the following two sentences are semantically similar:
#      1. a man is smoking.
#      2. a baby is sucking on a pacifier.
# You answered: True
#
# 157. True/False: the following two sentences are semantically similar:
#      1. a person is putting shredded cheese in a pot.
#      2. a hamster is eating some seeds.
# You answered: False
#
# 158. True/False: the following two sentences are semantically similar:
#      1. a man is erasing a chalk board.
#      2. a woman is dancing, and singing.
# You answered: False
#
# 159. True/False: the following two sentences are semantically similar:
#      1. a chimp is kicking a target.
#      2. a woman is putting oil into a skillet.
# You answered: False
#
# 160. True/False: the following two sentences are semantically similar:
#      1. a man is doing exercise.
#      2. a baby is laughing.
# You answered: False
#
# 161. True/False: the following two sentences are semantically similar:
#      1. the girl is carrying a baby.
#      2. a man is eating a food.
# You answered: True
#
# 162. True/False: the following two sentences are semantically similar:
#      1. a man spins on a surf board.
#      2. a man is putting barbecue sauce on chicken.
# You answered: False
#
# 163. True/False: the following two sentences are semantically similar:
#      1. two men are dancing together.
#      2. a woman opens a closet.
# You answered: False
#
# 164. True/False: the following two sentences are semantically similar:
#      1. a man is reading an email.
#      2. a person opening a banana.
# You answered: False
#
# 165. True/False: the following two sentences are semantically similar:
#      1. the flock of sheep are spread out in the field.
#      2. a white cat stands on the floor.
# You answered: False
#
# 166. True/False: the following two sentences are semantically similar:
#      1. a man sitting in a back yard playing the guitar.
#      2. a man riding on the back of an orange suv.
# You answered: True
#
# 167. True/False: the following two sentences are semantically similar:
#      1. a woman riding a brown horse.
#      2. a woman taking her own photo from above.
# You answered: False
#
# 168. True/False: the following two sentences are semantically similar:
#      1. two men standing in grass staring at a car.
#      2. a woman in a pink top posing with beer.
# You answered: False
#
# 169. True/False: the following two sentences are semantically similar:
#      1. the train heads down the tracks and along the hedge.
#      2. a dog on the floor of a patio looks at a cat on the fence.
# You answered: False
#
# 170. True/False: the following two sentences are semantically similar:
#      1. a little girl is laughing at the camera.
#      2. a white cow with big ears looking into the camera.
# You answered: False
#
# 171. True/False: the following two sentences are semantically similar:
#      1. a man dressed in a pale scarf with a stick.
#      2. a runner is resting in the shade with a bottle of soda.
# You answered: False
#
# 172. True/False: the following two sentences are semantically similar:
#      1. a very retro living room with a television in it.
#      2. a grey cat lying on a wooden table.
# You answered: False
#
# 173. True/False: the following two sentences are semantically similar:
#      1. a man sitting cross legged on the grass, with a tree in the background.
#      2. ocean liner close to coast with houses in the background.
# You answered: False
#
# 174. True/False: the following two sentences are semantically similar:
#      1. two men standing in grass staring at a car.
#      2. two women sitting in chairs in a shop.
# You answered: True
#
# 175. True/False: the following two sentences are semantically similar:
#      1. a woman stands in front of a building in the snow.
#      2. two women and a baby pose in front of a dining room.
# You answered: True
#
# 176. True/False: the following two sentences are semantically similar:
#      1. a yellow school bus parked in a field.
#      2. a brown horse in a green field.
# You answered: False
#
# 177. True/False: the following two sentences are semantically similar:
#      1. the cat is sitting on a bag of cat food.
#      2. two eagles sitting on a long branch.
# You answered: False
#
# 178. True/False: the following two sentences are semantically similar:
#      1. a women painting a chair with a dining room in the background.
#      2. a man and boy walking along a beach with the sea in the background.
# You answered: True
#
# 179. True/False: the following two sentences are semantically similar:
#      1. a cruise ship is in front of a docking area.
#      2. calico cat sitting on step in front of a door.
# You answered: False
#
# 180. True/False: the following two sentences are semantically similar:
#      1. a black and white cow standing in hay looks back at the camera.
#      2. there is a black and white sheep standing on the grass.
# You answered: True
#
# 181. True/False: the following two sentences are semantically similar:
#      1. two animals sitting on a rock.
#      2. the brown train is sitting on the railroad tracks.
# You answered: False
#
# 182. True/False: the following two sentences are semantically similar:
#      1. a small camouflaged airplane parked in the grass.
#      2. a small dog wearing a pink shirt tied to a railing.
# You answered: False
#
# 183. True/False: the following two sentences are semantically similar:
#      1. a man and a woman watch two dogs.
#      2. a man in a maroon bathing suit swings on a rope on a lake.
# You answered: False
#
# 184. True/False: the following two sentences are semantically similar:
#      1. a man and a woman are standing in front of a building
#      2. two girls are sitting on an atv on the sand in front of a bridge.
# You answered: True
#
# 185. True/False: the following two sentences are semantically similar:
#      1. a woman in a black and orange jacket throws a stick for a brown and black dog to fetch.
#      2. the man in a blue jacket is standing in a crowd.
# You answered: True
#
# 186. True/False: the following two sentences are semantically similar:
#      1. two racing dogs run in the mud.
#      2. the man is going into the water.
# You answered: False
#
# 187. True/False: the following two sentences are semantically similar:
#      1. a man in a suit dances with a young girl in front of an audience.
#      2. a women dangles from a blue fabric connected to a tree.
# You answered: True
#
# 188. True/False: the following two sentences are semantically similar:
#      1. a man and woman walking past a record shop
#      2. a man and woman kissing in front of a crowd of people.
# You answered: True
#
# 189. True/False: the following two sentences are semantically similar:
#      1. a boy in red jumping into a sandbox.
#      2. a dog swimming in a pond
# You answered: False
#
# 190. True/False: the following two sentences are semantically similar:
#      1. two people are in bed.
#      2. two boxers are in the ring.
# You answered: True
#
# 191. True/False: the following two sentences are semantically similar:
#      1. a red haired women in black is posing for a man while resting on a tree.
#      2. a man in a black shirt is holding a child wearing sunglasses.
# You answered: True
#
# 192. True/False: the following two sentences are semantically similar:
#      1. a dog standing in the water.
#      2. a girl playing on a parachute.
# You answered: False
#
# 193. True/False: the following two sentences are semantically similar:
#      1. a brown and white dog is running across a brown field.
#      2. a person hanging from a rocky cliff.
# You answered: True
#
# 194. True/False: the following two sentences are semantically similar:
#      1. a man in a wet suit is throwing a baby wearing a wet suit up into the air.
#      2. a man in a white print shirt and a woman in a black dress dancing.
# You answered: True
#
# 195. True/False: the following two sentences are semantically similar:
#      1. many football players sitting on the ground.
#      2. a dog rolls on the ground.
# You answered: False
#
# 196. True/False: the following two sentences are semantically similar:
#      1. a little boy and a little girl playing together outside.
#      2. a woman wearing a white shirt stands on the street.
# You answered: False
#
# 197. True/False: the following two sentences are semantically similar:
#      1. the woman is holding the harness that the brown and white dog is wearing.
#      2. a man and woman are looking at artwork that is on easels and clipped to a fencing wall.
# You answered: True
#
# 198. True/False: the following two sentences are semantically similar:
#      1. a young pitcher is throwing the baseball.
#      2. a brown dog is walking on the grass beside a fence.
# You answered: False
#
# 199. True/False: the following two sentences are semantically similar:
#      1. a woman in a blue bathing suit is jumping off a dock into a lake.
#      2. a boy in a blue shirt and blue jeans runs across a playground
# You answered: False
#
# 200. True/False: the following two sentences are semantically similar:
#      1. a little girl in an orange striped outfit is airborne whilst bouncing on a bed.
#      2. a dog in a red shirt is chasing a squirrel through the glass.
# You answered: True
#
# Answering part 3 (with POS weighting)...
# 1. True/False: the following two sentences are semantically similar:
#      1. one woman is measuring another woman's ankle.
#      2. a woman measures another woman's ankle.
# You answered: False
#
# 2. True/False: the following two sentences are semantically similar:
#      1. a man is cutting an onion.
#      2. a man cuts an onion.
# You answered: True
#
# 3. True/False: the following two sentences are semantically similar:
#      1. a young woman is putting stickers all over her face.
#      2. a woman is applying stickers to her face.
# You answered: True
#
# 4. True/False: the following two sentences are semantically similar:
#      1. a woman is dancing in the rain.
#      2. a woman dances in the rain out side.
# You answered: True
#
# 5. True/False: the following two sentences are semantically similar:
#      1. the man is kissing and hugging the woman.
#      2. a man is hugging and kissing a woman.
# You answered: True
#
# 6. True/False: the following two sentences are semantically similar:
#      1. a man is playing the guitar and singing.
#      2. a man sings with a guitar.
# You answered: True
#
# 7. True/False: the following two sentences are semantically similar:
#      1. a man is doing trick with play cards.
#      2. a man is performing a card trick.
# You answered: True
#
# 8. True/False: the following two sentences are semantically similar:
#      1. the lady peeled the potatoe.
#      2. a woman is peeling a potato.
# You answered: False
#
# 9. True/False: the following two sentences are semantically similar:
#      1. a woman and man are dancing in the rain.
#      2. a man and woman are dancing in rain.
# You answered: True
#
# 10. True/False: the following two sentences are semantically similar:
#      1. two men are fistfighting in a ring.
#      2. two men fistfight in a ring.
# You answered: False
#
# 11. True/False: the following two sentences are semantically similar:
#      1. a woman is stabbing a potato with a fork.
#      2. a woman is puncturing a potato with a fork.
# You answered: True
#
# 12. True/False: the following two sentences are semantically similar:
#      1. a boy is playing a key-board.
#      2. a little boy is playing a keyboard.
# You answered: True
#
# 13. True/False: the following two sentences are semantically similar:
#      1. a woman plays the flute.
#      2. a woman is playing the flute.
# You answered: True
#
# 14. True/False: the following two sentences are semantically similar:
#      1. a group of people are sweeping water out of a house.
#      2. people are sweeping water out of a house.
# You answered: True
#
# 15. True/False: the following two sentences are semantically similar:
#      1. a man plays a guitar.
#      2. a man is playing a guitar.
# You answered: True
#
# 16. True/False: the following two sentences are semantically similar:
#      1. a man is playing a musical keyboard.
#      2. a man is playing a keyboard piano.
# You answered: True
#
# 17. True/False: the following two sentences are semantically similar:
#      1. a man plays a trumpet.
#      2. a man is playing the trumpet.
# You answered: True
#
# 18. True/False: the following two sentences are semantically similar:
#      1. the man is eating.
#      2. a man is eating food.
# You answered: True
#
# 19. True/False: the following two sentences are semantically similar:
#      1. a person is slicing onions.
#      2. someone is slicing an onion.
# You answered: True
#
# 20. True/False: the following two sentences are semantically similar:
#      1. two dogs and one cat sitting on couch.
#      2. two dogs and a cat resting on a couch.
# You answered: True
#
# 21. True/False: the following two sentences are semantically similar:
#      1. two green and white trains sitting on the tracks.
#      2. two green and white trains are sitting on the train track.
# You answered: True
#
# 22. True/False: the following two sentences are semantically similar:
#      1. a man in a top hat rides a white horse.
#      2. a man with a top hat riding a white horse.
# You answered: True
#
# 23. True/False: the following two sentences are semantically similar:
#      1. blue and red plane in mid-air flight.
#      2. a blue and red airplane while in flight.
# You answered: True
#
# 24. True/False: the following two sentences are semantically similar:
#      1. a group of horses grazing in a field.
#      2. group of horses grazing in grassy field.
# You answered: True
#
# 25. True/False: the following two sentences are semantically similar:
#      1. three goats are being rounded up by a dog.
#      2. three goats are chased by a dog.
# You answered: True
#
# 26. True/False: the following two sentences are semantically similar:
#      1. train in a station.
#      2. a train in a station.
# You answered: True
#
# 27. True/False: the following two sentences are semantically similar:
#      1. a blue bird standing on a lawn.
#      2. blue bird standing on green grass.
# You answered: True
#
# 28. True/False: the following two sentences are semantically similar:
#      1. a green car parked at a saloon.
#      2. a green car parked outside the saloon.
# You answered: True
#
# 29. True/False: the following two sentences are semantically similar:
#      1. group of people sitting around a restaurant dining table.
#      2. a group of people sitting at a restaurant table.
# You answered: True
#
# 30. True/False: the following two sentences are semantically similar:
#      1. a philips flat-screen tv is shown with its two remote controls.
#      2. a phillips flat screen tv with two remote controls.
# You answered: True
#
# 31. True/False: the following two sentences are semantically similar:
#      1. the train sits at the train station.
#      2. a train parked at a train station.
# You answered: True
#
# 32. True/False: the following two sentences are semantically similar:
#      1. three people sit at a picnic table outside of a building painted like a union jack.
#      2. three people sit at an outdoor table in front of a building painted like the union jack.
# You answered: True
#
# 33. True/False: the following two sentences are semantically similar:
#      1. a bird flies across the water.
#      2. a bird flies above the water.
# You answered: True
#
# 34. True/False: the following two sentences are semantically similar:
#      1. the dog is running through a field.
#      2. a dog runs through a field.
# You answered: True
#
# 35. True/False: the following two sentences are semantically similar:
#      1. two boys playing a game of flag football.
#      2. two boys are playing flag football.
# You answered: True
#
# 36. True/False: the following two sentences are semantically similar:
#      1. one white boy and one black boy stand with arms around each other.
#      2. two young boys, one white and one black, are standing with their arms around each other.
# You answered: True
#
# 37. True/False: the following two sentences are semantically similar:
#      1. the two dogs are playing in the yard.
#      2. two dogs are playing on the grass.
# You answered: True
#
# 38. True/False: the following two sentences are semantically similar:
#      1. four children are playing on a trampoline.
#      2. four kids are jumping on a trampoline.
# You answered: True
#
# 39. True/False: the following two sentences are semantically similar:
#      1. a black dog running into the water.
#      2. a black dog running through water.
# You answered: True
#
# 40. True/False: the following two sentences are semantically similar:
#      1. a dog jumps into the water.
#      2. a dog is jumping into the water.
# You answered: True
#
# 41. True/False: the following two sentences are semantically similar:
#      1. a man and a dog on rocks on a beach.
#      2. a man and dog on a rocky seashore.
# You answered: True
#
# 42. True/False: the following two sentences are semantically similar:
#      1. two dogs are running in the field.
#      2. two dogs running in a field.
# You answered: True
#
# 43. True/False: the following two sentences are semantically similar:
#      1. two brown dogs runs through the water.
#      2. two brown dogs running through water.
# You answered: True
#
# 44. True/False: the following two sentences are semantically similar:
#      1. a man climbing a rock-face.
#      2. a man is climbing a rock wall.
# You answered: True
#
# 45. True/False: the following two sentences are semantically similar:
#      1. the surfer does a flip off of a wave.
#      2. a surfer does a flip on a wave.
# You answered: True
#
# 46. True/False: the following two sentences are semantically similar:
#      1. a blonde haired toddler swinging on a tire swing.
#      2. a blonde haired child is swinging on a tire swing.
# You answered: True
#
# 47. True/False: the following two sentences are semantically similar:
#      1. one boy is pushing another boy on a swing.
#      2. a boy is pushing another boy on the swings.
# You answered: True
#
# 48. True/False: the following two sentences are semantically similar:
#      1. two black dogs are playing on the grass.
#      2. two black dogs are playing in a grassy plain.
# You answered: True
#
# 49. True/False: the following two sentences are semantically similar:
#      1. a man in a black suit is surfing along a crashing wave.
#      2. a surfer wearing a black wet suit is riding a a white wave in the ocean.
# You answered: True
#
# 50. True/False: the following two sentences are semantically similar:
#      1. a man running on a track.
#      2. a man running track
# You answered: True
#
# 51. True/False: the following two sentences are semantically similar:
#      1. a man steers a blue boat past brightly colored houses.
#      2. a man driving a blue boat passes by some colorful houses.
# You answered: False
#
# 52. True/False: the following two sentences are semantically similar:
#      1. a deer jumps a fence.
#      2. a deer is jumping over a fence.
# You answered: False
#
# 53. True/False: the following two sentences are semantically similar:
#      1. a young person  deep in thought.
#      2. a young man deep in thought.
# You answered: True
#
# 54. True/False: the following two sentences are semantically similar:
#      1. some guy sitting on a couch watching television.
#      2. a guy is sitting on the couch watching tv
# You answered: True
#
# 55. True/False: the following two sentences are semantically similar:
#      1. there is a cook preparing food.
#      2. a cook is making food.
# You answered: True
#
# 56. True/False: the following two sentences are semantically similar:
#      1. people gathered in a room.
#      2. people gathered together in a room.
# You answered: True
#
# 57. True/False: the following two sentences are semantically similar:
#      1. people getting their dirty clothes cleaned
#      2. people are getting their clothes cleaned.
# You answered: True
#
# 58. True/False: the following two sentences are semantically similar:
#      1. a man is laughing with a woman
#      2. a man and a woman laughing.
# You answered: True
#
# 59. True/False: the following two sentences are semantically similar:
#      1. the people are running a marathon
#      2. people are running a marathon
# You answered: True
#
# 60. True/False: the following two sentences are semantically similar:
#      1. a brown dog is jumping.
#      2. a brown dog is jumping
# You answered: True
#
# 61. True/False: the following two sentences are semantically similar:
#      1. you do not need to worry.
#      2. you don't have to worry.
# You answered: True
#
# 62. True/False: the following two sentences are semantically similar:
#      1. you can do it, too.
#      2. yes, you can do it.
# You answered: True
#
# 63. True/False: the following two sentences are semantically similar:
#      1. the answer to both questions is: yes.
#      2. the answer to both of your questions is yes.
# You answered: True
#
# 64. True/False: the following two sentences are semantically similar:
#      1. you guys are making this all waaaaay too complicated.
#      2. you are making this too complicated.
# You answered: True
#
# 65. True/False: the following two sentences are semantically similar:
#      1. it's not a good idea.
#      2. it is not a good idea.
# You answered: True
#
# 66. True/False: the following two sentences are semantically similar:
#      1. take a look at these:
#      2. take a look at this:
# You answered: True
#
# 67. True/False: the following two sentences are semantically similar:
# ...
#      1. a man is opening a box and taking out paper.
#      2. a woman is peeling a potato.
# You answered: False
#
# 116. True/False: the following two sentences are semantically similar:
#      1. a woman is cracking eggs.
#      2. a man is talking to a woman.
# You answered: False
#
# 117. True/False: the following two sentences are semantically similar:
#      1. a cat is walking around a house.
#      2. a woman is peeling potato.
# You answered: False
#
# 118. True/False: the following two sentences are semantically similar:
#      1. a woman is talking to her pet bunny as she fondles it.
#      2. a woman walks her dog onto astro turf.
# You answered: False
#
# 119. True/False: the following two sentences are semantically similar:
#      1. a man is playing guitar.
#      2. a boy is talking to a giant dog.
# You answered: False
#
# 120. True/False: the following two sentences are semantically similar:
#      1. a cat is playing on the floor.
#      2. a man is slicing garlic.
# You answered: False
#
# 121. True/False: the following two sentences are semantically similar:
#      1. a boy is playing violin on stage.
#      2. a person is mixing a pot.
# You answered: False
#
# 122. True/False: the following two sentences are semantically similar:
#      1. a woman is slicing ginger.
#      2. a person is holding two baby lorises.
# You answered: False
#
# 123. True/False: the following two sentences are semantically similar:
#      1. a woman is spreading mustard on a bread roll.
#      2. a kitten is playing with a woman's finger.
# You answered: False
#
# 124. True/False: the following two sentences are semantically similar:
#      1. someone touched the kitten chewing on a string.
#      2. someone is cutting paper.
# You answered: False
#
# 125. True/False: the following two sentences are semantically similar:
#      1. meat is being put into a skillet.
#      2. a woman is putting a baby into a trash can.
# You answered: True
#
# 126. True/False: the following two sentences are semantically similar:
#      1. a baby elephant is eating a small tree.
#      2. a little girl peddling a scooter.
# You answered: False
#
# 127. True/False: the following two sentences are semantically similar:
#      1. someone is drawing.
#      2. someone is dancing.
# You answered: False
#
# 128. True/False: the following two sentences are semantically similar:
#      1. a person is playing a piano.
#      2. a person is slicing a potato.
# You answered: False
#
# 129. True/False: the following two sentences are semantically similar:
#      1. a man is dancing.
#      2. a woman is exercising.
# You answered: True
#
# 130. True/False: the following two sentences are semantically similar:
#      1. a woman is exercising.
#      2. a man is dancing.
# You answered: True
#
# 131. True/False: the following two sentences are semantically similar:
#      1. a man is doing exercise.
#      2. a man is firing a rifle.
# You answered: False
#
# 132. True/False: the following two sentences are semantically similar:
#      1. a man is playing a piano.
#      2. a guy is peeling a potato.
# You answered: False
#
# 133. True/False: the following two sentences are semantically similar:
#      1. a man is bowling.
#      2. a kitten is walking.
# You answered: False
#
# 134. True/False: the following two sentences are semantically similar:
#      1. a woman is dancing near a fire.
#      2. a woman is cutting a tomatoe.
# You answered: False
#
# 135. True/False: the following two sentences are semantically similar:
#      1. a person is riding a motorcyle.
#      2. a person is chopping an onion.
# You answered: False
#
# 136. True/False: the following two sentences are semantically similar:
#      1. a man is talking on the phone.
#      2. a man is moon-walking across a store.
# You answered: True
#
# 137. True/False: the following two sentences are semantically similar:
#      1. a woman is braiding her hair.
#      2. a man is riding a motorcycle.
# You answered: False
#
# 138. True/False: the following two sentences are semantically similar:
#      1. the woman is slicing tofu.
#      2. the woman is putting on lipstick.
# You answered: True
#
# 139. True/False: the following two sentences are semantically similar:
#      1. a woman is folding paper.
#      2. a woman is applying eye shadow.
# You answered: False
#
# 140. True/False: the following two sentences are semantically similar:
#      1. someone is folding a piece of paper.
#      2. a person is slicing a small pieces of ginger.
# You answered: True
#
# 141. True/False: the following two sentences are semantically similar:
#      1. a man is lifting weights.
#      2. a man is chopping egg plant.
# You answered: False
#
# 142. True/False: the following two sentences are semantically similar:
#      1. a man is playing a cello.
#      2. a man is rapidly lifting small weights.
# You answered: False
#
# 143. True/False: the following two sentences are semantically similar:
#      1. the man is talking.
#      2. a man is walking down stairs.
# You answered: True
#
# 144. True/False: the following two sentences are semantically similar:
#      1. a man is playing the drums.
#      2. a woman is slicing some leaves.
# You answered: False
#
# 145. True/False: the following two sentences are semantically similar:
#      1. a man is hitting a boy with flower vase.
#      2. a man is cutting a mat.
# You answered: True
#
# 146. True/False: the following two sentences are semantically similar:
#      1. the man is mixing whipping cream.
#      2. the man is holding a skunk.
# You answered: False
#
# 147. True/False: the following two sentences are semantically similar:
#      1. a man is singing while playing the guitar.
#      2. a man is stuffing himself full with food.
# You answered: False
#
# 148. True/False: the following two sentences are semantically similar:
#      1. a boat sails along the water.
#      2. the man is playing the guitar.
# You answered: False
#
# 149. True/False: the following two sentences are semantically similar:
#      1. an okapi is eating from a tree.
#      2. a moose drinks from a sprinkler.
# You answered: False
#
# 150. True/False: the following two sentences are semantically similar:
#      1. a woman is pouring egg into a frying pan.
#      2. a man is petting two dogs.
# You answered: False
#
# 151. True/False: the following two sentences are semantically similar:
#      1. a woman is frying ground meat.
#      2. a man is cutting a trunk with an axe.
# You answered: False
#
# 152. True/False: the following two sentences are semantically similar:
#      1. a person is boiling noodles.
#      2. a cat is licking a bottle.
# You answered: False
#
# 153. True/False: the following two sentences are semantically similar:
#      1. a man reels in a fish.
#      2. a woman is pouring oil in a bowl.
# You answered: False
#
# 154. True/False: the following two sentences are semantically similar:
#      1. a woman is cutting an onion.
#      2. a horse is standing.
# You answered: False
#
# 155. True/False: the following two sentences are semantically similar:
#      1. a person is adding food in a pan.
#      2. a man is dancing in the street.
# You answered: False
#
# 156. True/False: the following two sentences are semantically similar:
#      1. a man is smoking.
#      2. a baby is sucking on a pacifier.
# You answered: False
#
# 157. True/False: the following two sentences are semantically similar:
#      1. a person is putting shredded cheese in a pot.
#      2. a hamster is eating some seeds.
# You answered: False
#
# 158. True/False: the following two sentences are semantically similar:
#      1. a man is erasing a chalk board.
#      2. a woman is dancing, and singing.
# You answered: False
#
# 159. True/False: the following two sentences are semantically similar:
#      1. a chimp is kicking a target.
#      2. a woman is putting oil into a skillet.
# You answered: False
#
# 160. True/False: the following two sentences are semantically similar:
#      1. a man is doing exercise.
#      2. a baby is laughing.
# You answered: False
#
# 161. True/False: the following two sentences are semantically similar:
#      1. the girl is carrying a baby.
#      2. a man is eating a food.
# You answered: False
#
# 162. True/False: the following two sentences are semantically similar:
#      1. a man spins on a surf board.
#      2. a man is putting barbecue sauce on chicken.
# You answered: False
#
# 163. True/False: the following two sentences are semantically similar:
#      1. two men are dancing together.
#      2. a woman opens a closet.
# You answered: False
#
# 164. True/False: the following two sentences are semantically similar:
#      1. a man is reading an email.
#      2. a person opening a banana.
# You answered: False
#
# 165. True/False: the following two sentences are semantically similar:
#      1. the flock of sheep are spread out in the field.
#      2. a white cat stands on the floor.
# You answered: False
#
# 166. True/False: the following two sentences are semantically similar:
#      1. a man sitting in a back yard playing the guitar.
#      2. a man riding on the back of an orange suv.
# You answered: False
#
# 167. True/False: the following two sentences are semantically similar:
#      1. a woman riding a brown horse.
#      2. a woman taking her own photo from above.
# You answered: False
#
# 168. True/False: the following two sentences are semantically similar:
#      1. two men standing in grass staring at a car.
#      2. a woman in a pink top posing with beer.
# You answered: False
#
# 169. True/False: the following two sentences are semantically similar:
#      1. the train heads down the tracks and along the hedge.
#      2. a dog on the floor of a patio looks at a cat on the fence.
# You answered: False
#
# 170. True/False: the following two sentences are semantically similar:
#      1. a little girl is laughing at the camera.
#      2. a white cow with big ears looking into the camera.
# You answered: False
#
# 171. True/False: the following two sentences are semantically similar:
#      1. a man dressed in a pale scarf with a stick.
#      2. a runner is resting in the shade with a bottle of soda.
# You answered: False
#
# 172. True/False: the following two sentences are semantically similar:
#      1. a very retro living room with a television in it.
#      2. a grey cat lying on a wooden table.
# You answered: False
#
# 173. True/False: the following two sentences are semantically similar:
#      1. a man sitting cross legged on the grass, with a tree in the background.
#      2. ocean liner close to coast with houses in the background.
# You answered: False
#
# 174. True/False: the following two sentences are semantically similar:
#      1. two men standing in grass staring at a car.
#      2. two women sitting in chairs in a shop.
# You answered: False
#
# 175. True/False: the following two sentences are semantically similar:
#      1. a woman stands in front of a building in the snow.
#      2. two women and a baby pose in front of a dining room.
# You answered: True
#
# 176. True/False: the following two sentences are semantically similar:
#      1. a yellow school bus parked in a field.
#      2. a brown horse in a green field.
# You answered: False
#
# 177. True/False: the following two sentences are semantically similar:
#      1. the cat is sitting on a bag of cat food.
#      2. two eagles sitting on a long branch.
# You answered: False
#
# 178. True/False: the following two sentences are semantically similar:
#      1. a women painting a chair with a dining room in the background.
#      2. a man and boy walking along a beach with the sea in the background.
# You answered: False
#
# 179. True/False: the following two sentences are semantically similar:
#      1. a cruise ship is in front of a docking area.
#      2. calico cat sitting on step in front of a door.
# You answered: False
#
# 180. True/False: the following two sentences are semantically similar:
#      1. a black and white cow standing in hay looks back at the camera.
#      2. there is a black and white sheep standing on the grass.
# You answered: True
#
# 181. True/False: the following two sentences are semantically similar:
#      1. two animals sitting on a rock.
#      2. the brown train is sitting on the railroad tracks.
# You answered: False
#
# 182. True/False: the following two sentences are semantically similar:
#      1. a small camouflaged airplane parked in the grass.
#      2. a small dog wearing a pink shirt tied to a railing.
# You answered: False
#
# 183. True/False: the following two sentences are semantically similar:
#      1. a man and a woman watch two dogs.
#      2. a man in a maroon bathing suit swings on a rope on a lake.
# You answered: False
#
# 184. True/False: the following two sentences are semantically similar:
#      1. a man and a woman are standing in front of a building
#      2. two girls are sitting on an atv on the sand in front of a bridge.
# You answered: True
#
# 185. True/False: the following two sentences are semantically similar:
#      1. a woman in a black and orange jacket throws a stick for a brown and black dog to fetch.
#      2. the man in a blue jacket is standing in a crowd.
# You answered: True
#
# 186. True/False: the following two sentences are semantically similar:
#      1. two racing dogs run in the mud.
#      2. the man is going into the water.
# You answered: False
#
# 187. True/False: the following two sentences are semantically similar:
#      1. a man in a suit dances with a young girl in front of an audience.
#      2. a women dangles from a blue fabric connected to a tree.
# You answered: False
#
# 188. True/False: the following two sentences are semantically similar:
#      1. a man and woman walking past a record shop
#      2. a man and woman kissing in front of a crowd of people.
# You answered: True
#
# 189. True/False: the following two sentences are semantically similar:
#      1. a boy in red jumping into a sandbox.
#      2. a dog swimming in a pond
# You answered: False
#
# 190. True/False: the following two sentences are semantically similar:
#      1. two people are in bed.
#      2. two boxers are in the ring.
# You answered: False
#
# 191. True/False: the following two sentences are semantically similar:
#      1. a red haired women in black is posing for a man while resting on a tree.
#      2. a man in a black shirt is holding a child wearing sunglasses.
# You answered: True
#
# 192. True/False: the following two sentences are semantically similar:
#      1. a dog standing in the water.
#      2. a girl playing on a parachute.
# You answered: False
#
# 193. True/False: the following two sentences are semantically similar:
#      1. a brown and white dog is running across a brown field.
#      2. a person hanging from a rocky cliff.
# You answered: False
#
# 194. True/False: the following two sentences are semantically similar:
#      1. a man in a wet suit is throwing a baby wearing a wet suit up into the air.
#      2. a man in a white print shirt and a woman in a black dress dancing.
# You answered: True
#
# 195. True/False: the following two sentences are semantically similar:
#      1. many football players sitting on the ground.
#      2. a dog rolls on the ground.
# You answered: False
#
# 196. True/False: the following two sentences are semantically similar:
#      1. a little boy and a little girl playing together outside.
#      2. a woman wearing a white shirt stands on the street.
# You answered: False
#
# 197. True/False: the following two sentences are semantically similar:
#      1. the woman is holding the harness that the brown and white dog is wearing.
#      2. a man and woman are looking at artwork that is on easels and clipped to a fencing wall.
# You answered: True
#
# 198. True/False: the following two sentences are semantically similar:
#      1. a young pitcher is throwing the baseball.
#      2. a brown dog is walking on the grass beside a fence.
# You answered: False
#
# 199. True/False: the following two sentences are semantically similar:
#      1. a woman in a blue bathing suit is jumping off a dock into a lake.
#      2. a boy in a blue shirt and blue jeans runs across a playground
# You answered: False
#
# 200. True/False: the following two sentences are semantically similar:
#      1. a little girl in an orange striped outfit is airborne whilst bouncing on a bed.
#      2. a dog in a red shirt is chasing a squirrel through the glass.
# You answered: True
#
# accuracy (regular): 0.78000
# accuracy with POS weighting: 0.88000
# (0.78, 0.88)

# %% [markdown]
# # Part 4: Exploration
# In this section, you'll do an exploration question. Specifically, you'll implement the following 2 functions:
#
# * **occupation_exploration()**: given a list of occupations, find the top 5 occupations with the highest cosine similarity to the word "man", and the top 5 occupations with the highest cosine similarity to the word "woman".
# * **part4_written()**: look at your results from the previous exploration task. What do you observe, and why do you think this might be the case? Write your answer within the function by returning a string.

# %%
def occupation_exploration(occupations, embeddings):
    '''
    Given a list of occupations, return the 5 occupations that are closest
    to 'man', and the 5 closest to 'woman', using cosine similarity between
    corresponding word embeddings as a measure of similarity.

    Arguments:
        occupations (list): list of occupations (strings)
        embeddings (map): map of words (strings) to their embeddings (np vectors)

    Returns:
        top_man_occs (list): list of 5 occupations (strings) closest to 'man'
        top_woman_occs (list): list of 5 occuptions (strings) closest to 'woman'
            note: both lists should be sorted, with the occupation with highest
                  cosine similarity first in the list
    '''
    top_man_occs = []
    top_woman_occs = []
    #########################################################
    ## TODO: get 5 occupations closest to 'man' & 'woman'  ##
    #########################################################
    
    man_emb, woman_emb = embeddings['man'], embeddings['woman']
    occ_embs = [embeddings[occ] for occ in occupations]
    
    man_occs = np.array([cosine_similarity(occ_emb, man_emb) for occ_emb in occ_embs])
    top_man_occs = [occupations[i] for i in np.argsort(-1*man_occs)[:5]]
    
    woman_occs = np.array([cosine_similarity(occ_emb, woman_emb) for occ_emb in occ_embs])
    top_woman_occs = [occupations[i] for i in np.argsort(-1*woman_occs)[:5]]
    
    #########################################################
    ## End TODO                                            ##
    #########################################################
    return top_man_occs, top_woman_occs

def part4_written():
    '''
    Take a look at what occupations you found are closest to 'man' and
    closest to 'woman'. Do you notice anything curious? In 1-2 sentences,
    describe what you find, and why you think this occurs.
    '''
    #########################################################
    ## TODO: replace string with your answer               ##
    ######################################################### 
    answer = """
    It is no surprise to see nurse at the top of the occupation list for woman, but for man I would
    give more weights to occupations like warrior or lawyer compared to the top occupation teacher.
    """
    #########################################################
    ## End TODO                                            ##
    ######################################################### 
    return answer

# %%
part4 = quizlet.Part4_Runner(occupation_exploration, part4_written)
part4.evaluate()
# Out:
# Part 4: Exploration!
# --------------------
# occupations closest to "man" - you answered:
#  1. teacher
#  2. actor
#  3. worker
#  4. lawyer
#  5. warrior
# occupations closest to "woman" - you answered:
#  1. nurse
#  2. teacher
#  3. worker
#  4. maid
#  5. waitress
# (['teacher', 'actor', 'worker', 'lawyer', 'warrior'],
#  ['nurse', 'teacher', 'worker', 'maid', 'waitress'])

# %% [markdown]
# # Part 5: Entity Representation
#
# Entities can be detected in text using a Named Entity Recognition (NER) Model. Luckily many such models exist and can be employed off-the-shelf for decent performance. In this section, we will take a corpus of documents from Wikipedia and extract named entities from them by using the NER model from SpaCy.
#
# Once we've extracted entities, we might be interested in finding which ones are similar to each other.
#
# Like any other words, entities have vector representations. However, since we are working with a fixed vocabulary, it is likely that we won't find all our entities in the vocabulary.
#
# One simple way to create entity representations is to take the mean of the text description of the entity. In this assignment, for each entity we have a description from Wikipedia. You will implement a function that computes an entity representation by taking the mean of the embeddings of the description. Note that not all the words in the description are in our vocabulary, so skip those. Also, using embeddings of stop words might add noise to averaged embeddings, so let's skip those words as well. _Note: SpaCy token objects have an Token.is_stop field that you can use for this._
#
# Once we've computed embeddings for each entity, we might be interested in finding entities that are similar to each other. For each entity, let's find the top 5 most similar entities. _Note: For fast computation, you might want to vectorize your cosine similarity computation._
#
# We have a dataset of annotated similar entities. Let's see how well we do on this benchmark and then let's visually inspect our similar entities to see how coherent they seem.
#
# _Question: Do you see any patterns in entities that are similar? Do you see any systematic mistakes?_

# %%
# You will use SpaCy to extact Named Entities
import spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en_core_web_sm==2.3.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 211 kB/s eta 0:00:01
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from en_core_web_sm==2.3.1) (2.3.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.25.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (4.61.2)
# Requirement already satisfied: setuptools in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (52.0.0.post20210125)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.8.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.1.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.7.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.5)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (7.4.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.5)
# Requirement already satisfied: numpy>=1.15.0 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.20.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.0.5)
# Requirement already satisfied: importlib-metadata>=0.20 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.10.0)
# Requirement already satisfied: zipp>=0.5 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.7.4.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/pchen/yes/envs/cs231n/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.26.4)
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py) ... done
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.3.1-py3-none-any.whl size=12047106 sha256=f59e8c1885addc6b642197888faa514a7545eeb50e85c83b9eeb8900a3df794a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ppec_ojr/wheels/b7/0d/f0/7ecae8427c515065d75410989e15e5785dd3975fe06e795cd9
# Successfully built en-core-web-sm
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-2.3.1
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
def extract_named_entities(paragraph):
    '''
    This function will be fed 1 paragraph at a time.
    See the documentation for using the SpaCy API (https://spacy.io/) to convert 
    the paragraphs to Spacy Documents. The processing automatically runs an NER model.
    You should be able to use a simple field on the Document object to return
    the  entities in the paragraph.
    https://spacy.io/usage/linguistic-features#named-entities
    '''
    spacy_paragraph = None
    named_entities = []
    #########################################################
    ## Process paragraph with SpaCy and extract entities.  ##
    #########################################################
    
    spacy_paragraph = nlp(paragraph)
    named_entities = spacy_paragraph.ents

    #########################################################
    ## End TODO                                            ##
    #########################################################
    return named_entities, spacy_paragraph
    
def compute_entity_representation(description, embeddings):
    '''
    For each entity, we will use the description to build an entity representation.
    Use the embeddings as before to get an emebedding for each word in the description.
    Note that the description is a Spacy.Document so access the raw text accordingly.
    Note that you probably want to use lower case lookup in the embddings table.
    Take the mean of all words from the description that appear in the vocabulary and 
    that are NOT stop words.
    Note: SpaCy Tokens have a Token.is_stop field.
    '''
    vector = None
    #########################################################
    ## TODO: Compute embedding for entity                  ##
    #########################################################
    
    embs = np.array([embeddings[str(tok).lower()] for tok in description \
                     if str(tok).lower() in embeddings and not tok.is_stop])
    vector = embs.sum(axis=0)
    
    #########################################################
    ## End TODO                                            ##
    #########################################################
    return vector
    
def get_top_k_similar(entity, entity_embedding, options, top_k):
    '''
    For this function, you are given an entity name, the embedding for that entity,
    and a dictionary of options ({entity_name: entity_embedding}). 
    Return the top k (string) entities that are most similar to the provided entity.
    This function will be called many times and compared with many entities so you should 
    optimize your cosine similarity function. You can parallelize the computation using
    a matrix multiplication.
    
    Arguments:
        entity (string): text of an entity
        entity_embedding (numpy array): the vector embedding for the entity
        options (map {string -> numpy array}): similar to the above entity and embedding,
            this is a dictionary of all the options to choose from.
        top_k (int): size of return

    Returns:
        similar_entities (list of strings): this should be of size top_k
    
    '''
    similar_entities = []
    #########################################################
    ## TODO: return similar k entities                     ##
    #########################################################
    
    ent_emb = [(ent, emb) for ent, emb in options.items()]
    emb_mat = np.array([emb for (ent, emb) in ent_emb])
    emb_mat_unit = emb_mat/np.sqrt(np.sum(emb_mat**2, axis=1, keepdims=True))
    ent_emb_unit = entity_embedding/np.sqrt(np.sum(entity_embedding**2))
    cosines = np.sum(emb_mat_unit*ent_emb_unit, axis=1)
    similar_entities = [ent_emb[i][0] for i in np.argsort(-1*cosines)[:top_k]]
  
    #########################################################
    ## End TODO                                            ##
    #########################################################
    return similar_entities

# %%
# Note: You may want to put the below function and function call into a 
# loop to find a good threshold.

def compute_entity_similarity(entity_representation_1, entity_representation_2):
    '''
    Compute the similarity between these two entities. Since we are doing a binary
    classification task, you'll want to find a good threshold to convert from a 
    cosine similarity score to a boolean value.
    '''
    #########################################################
    ## TODO: Compute similarity between two entities       ##
    #########################################################
    sim = cosine_similarity(entity_representation_1, entity_representation_2)
    
    return sim > 0.99
    #########################################################
    ## End TODO                                            ##
    #########################################################

# %%
part5 = quizlet.Part5_Runner(extract_named_entities, compute_entity_representation,
                            compute_entity_similarity, get_top_k_similar)

# This part may take >10 seconds to complete
part5.build_representations()

# You should have found over 4,000 unique entity mentions
# Out:
# Total entities found:  4177
# 4177

# %%
# This is just overwriting the function in the runner class so you can run this 
# cell many times to test different thresholds.
part5.compute_entity_similarity = compute_entity_similarity
part5.evaluate(True)  # Pass in false to not print out top k similar entities 

# You should be able to get above 85% accuracy on the binary entity similarity task
# You should be able to  get above 10% on the top 5 similar entities task.
# Out:
# Let's see how well we do at the entity similarity benchmark:
# Accuracy: 0.8669438669438669
# Now let's see if we can find the top k most similar entities to each entity.
# Entity: Ferrari
# Similar entities: ['Lamborghini', 'Alfa Romeo', 'Royal Shakespeare Company', 'Bugatti', 'ConAgra Foods']
# Entity: River Kent
# Similar entities: ['London', 'Wales', 'Mount St. Helens', 'Tallinn', 'Grand Teton']
# Entity: Ronald Reagan
# Similar entities: ['Dick Cheney', 'Barack Obama', 'Jimmy Carter', 'Richard Nixon', 'George W. Bush']
# Entity: Mount St. Helens
# Similar entities: ['Eritrea', 'Mozambique', 'Wales', 'Hawaii', 'Greenland']
# Entity: Asia
# Similar entities: ['Oceania', 'Africa', 'Zagreb', 'Nepal', 'United States']
# Entity: Modern Gallery, Zagreb
# Similar entities: ['National Roman Museum', 'Hungarian Natural History Museum', 'Indonesia Museum', 'Vatican Hill', 'Museo del Prado']
# Entity: F.C. Dynamo Voronezh
# Similar entities: ['Wayne Gretzky', 'Tom Brady', 'Lionel Messi', 'Seattle Mariners', 'St. Louis Cardinals']
# Entity: New York City
# Similar entities: ['Los Angeles', 'Hawaii', 'New Jersey', 'New York Mercantile Exchange', 'Columbus, Ohio']
# Entity: Vladimir Putin
# Similar entities: ['Dilma Rousseff', 'Leon Trotsky', 'Alexander Hamilton', 'Kim Jong-il', 'Jimmy Carter']
# Entity: Condé Nast
# Similar entities: ['Ralph Lauren', "McDonald's", 'DuPont', 'Miller Brewing Company', 'Bill Gates']
# Entity: Iraq
# Similar entities: ['Syria', 'Afghanistan', 'Algeria', 'Sudan', 'Serbia']
# Entity: Rocky Mountains
# Similar entities: ['Mississippi River', 'North America', 'Ural Mountains', 'Colorado River', 'Europe']
# Entity: Cambodia
# Similar entities: ['Albania', 'Guangzhou', 'Sudan', 'Mozambique', 'Laos']
# Entity: Michael Jordan
# Similar entities: ['Derek Jeter', 'Stone Cold Steve Austin', 'Wayne Gretzky', 'Seattle Mariners', 'Edmonton Oilers']
# Entity: The Louvre
# Similar entities: ['Ringo Starr', 'Alanis Morissette', 'Cher', 'George Harrison', 'Dean Koontz']
# Entity: Brad Pitt
# Similar entities: ['George Clooney', 'Charlize Theron', 'Angelina Jolie', 'Ben Affleck', 'Rosario Dawson']
# Entity: Volga River
# Similar entities: ['Dnieper', 'Russia', 'Danube', 'Kiev', 'Moldova']
# Entity: Italy
# Similar entities: ['Mount Etna', 'Dominican Republic', 'Mount vesuvius', 'Madrid', 'Luxembourg']
# Entity: Blue Ridge Mountains
# Similar entities: ['Rocky Mountains', 'Colorado River', 'North America', 'New Jersey', 'Mississippi River']
# Entity: Technical University Munich
# Similar entities: ['University of Hamburg', 'Albert Einstein', 'Leipzig University', 'University of Oslo', 'University of Notre Dame']
# Entity: Moscow
# Similar entities: ['Berlin', 'Vienna', 'Russia', 'Kiev', 'Beijing']
# Entity: University of Missouri
# Similar entities: ['University of North Carolina at Greensboro', 'Stanford University', 'Princeton University', 'University of the Punjab', 'University of Delhi']
# Entity: England
# Similar entities: ['United Kingdom', 'Australia', 'Europe', 'Rocky Mountains', 'North America']
# Entity: European Space Agency
# Similar entities: ['United Airways', 'Lufthansa', 'Aeroflot', 'Madrid', 'Austria']
# Entity: Real Madrid C.F.
# Similar entities: ['FC Barcelona', 'Paris Saint-Germain F.C.', 'Manchester United F.C.', 'F.C. Bayern Munich', 'Zinedine Zidane']
# Entity: Oxfam
# Similar entities: ['National Rifle Association', 'National Endowment for the Arts', 'Julian Assange', 'World Economic Forum', 'Electronic Frontier Foundation']
# Entity: Bill Clinton
# Similar entities: ['John F. Kennedy', 'Woodrow Wilson', 'Hillary Rodham Clinton', 'Barack Obama', 'John Kerry']
# Entity: Mount St. Helens
# Similar entities: ['Eritrea', 'Mozambique', 'Wales', 'Hawaii', 'Greenland']
# Entity: University of Toronto
# Similar entities: ['University of Delhi', 'University of Cambridge', 'Stanford University', 'University of the Punjab', 'London School of Economics']
# Entity: Franklin D. Roosevelt
# Similar entities: ['Woodrow Wilson', 'Libertarian Party', 'Winston Churchill', 'John F. Kennedy', 'Alexander Hamilton']
# Entity: Munich
# Similar entities: ['Hamburg', 'Madrid', 'Kiev', 'Berlin', 'Austria']
# Entity: Tony Blair
# Similar entities: ['Winston Churchill', 'Gordon Brown', 'Nelson Mandela', 'David Cameron', 'Franklin D. Roosevelt']
# Entity: Russia
# Similar entities: ['Danube', 'Volga River', 'Kyrgyzstan', 'Kiev', 'Tajikistan']
# Entity: British Airways
# Similar entities: ['Cayman Airways', 'Emirates (airline)', 'Boeing', 'Air Canada', 'United Airways']
# Entity: Vatican Museums
# Similar entities: ['Museo del Prado', 'National Roman Museum', 'Indonesia Museum', 'Modern Gallery, Zagreb', 'Shanghai art museum']
# Entity: Danube
# Similar entities: ['Hungary', 'Russia', 'Volga River', 'Dnieper', 'Sudan']
# Entity: Danielle Steel
# Similar entities: ['John Steinbeck', 'J. K. Rowling', 'bell hooks', 'Dean Koontz', 'Maya Angelou']
# Entity: Greece
# Similar entities: ['Nepal', 'India', 'Portugal', 'Jakarta', 'Singapore']
# Entity: Puerto Rico
# Similar entities: ['The Bahamas', 'Eritrea', 'Dominican Republic', 'Panama', 'Colombia']
# Entity: Jon Stewart
# Similar entities: ['Stephen Colbert', 'Antonio Banderas', 'Groucho Marx', 'David Sedaris', 'Martha Stewart']
# Entity: Maya Angelou
# Similar entities: ['Toshiro Mifune', 'Danielle Steel', 'Angelina Jolie', 'Stephen King', 'William Shakespeare']
# Entity: Denmark
# Similar entities: ['Greenland', 'Lithuania', 'Portugal', 'Cameroon', 'Turkey']
# Entity: Aristotle
# Similar entities: ['Pythagoras', 'Confucius', 'Fyodor Dostoyevsky', 'Jesus', 'bell hooks']
# Entity: Martin Luther King, Jr.
# Similar entities: ['Winston Churchill', 'Oliver Cromwell', 'David Cameron', 'Leon Trotsky', 'Barack Obama']
# Entity: Karl Marx
# Similar entities: ['Martin Luther', 'Leipzig University', 'J.R.R. Tolkien', 'Fyodor Dostoyevsky', 'Karl Lagerfeld']
# Entity: Barack Obama
# Similar entities: ['Hillary Rodham Clinton', 'Richard Nixon', 'Dick Cheney', 'Jimmy Carter', 'John Kerry']
# Entity: Matterhorn
# Similar entities: ['Mount Etna', 'Hamburg', 'Danube', 'Russia', 'Kyrgyzstan']
# Entity: Leon Trotsky
# Similar entities: ['Catherine the Great', 'Kim Jong-il', 'Winston Churchill', 'Franklin D. Roosevelt', 'John F. Kennedy']
# Entity: Bugatti
# Similar entities: ['Ferrari', 'Alfa Romeo', 'Dale Earnhardt, Jr.', 'Himeji Castle', 'Mercedes-Benz']
# Entity: Daniel Radcliffe
# Similar entities: ['Leonard Nimoy', 'George Takei', 'Fred Astaire', 'Abhishek Bachchan', 'Akira Kurosawa']
# Entity: Minas Tirith
# Similar entities: ['Minas Morgul', 'Seoul', 'Moscow Kremlin', 'Mauretania', 'Bogotá']
# Entity: Iceland
# Similar entities: ['Tunisia', 'Catskill Mountains', 'Mumbai', 'Jakarta', 'Greece']
# Entity: William Shatner
# Similar entities: ['George Takei', 'David Tennant', 'Leonard Nimoy', 'Antonio Banderas', 'Stephen Colbert']
# Entity: Brazil
# Similar entities: ['Munich', 'United States', 'Panama', 'Austria', 'Madrid']
# Entity: Shanghai Sharks
# Similar entities: ['Phoenix Suns', 'Edmonton Oilers', 'Seattle Mariners', 'Zinedine Zidane', 'Derek Jeter']
# Entity: Volga River
# Similar entities: ['Dnieper', 'Russia', 'Danube', 'Kiev', 'Moldova']
# Entity: American Civil Liberties Union
# Similar entities: ['National Rifle Association', 'National Association for the Advancement of Colored People', 'National Endowment for the Arts', 'World Economic Forum', 'United Nations Human Rights Council']
# Entity: Jane Austen
# Similar entities: ['Lord Byron', 'Martin Luther', 'Gustav Mahler', 'Ernest Hemingway', 'Oda Nobunaga']
# Entity: American Red Cross
# Similar entities: ['Federal Highway Administration', 'Oxfam', 'Hungarian Natural History Museum', 'National Endowment for the Arts', 'International Olympic Committee']
# Entity: New Jersey
# Similar entities: ['New York City', 'Columbus, Ohio', 'Wyoming', 'California', 'Catskill Mountains']
# Entity: Shanghai art museum
# Similar entities: ['Rijksmuseum', 'Forbidden City', 'National Roman Museum', 'Vatican Museums', 'Indonesia Museum']
# Entity: Royal Swedish Academy of Sciences
# Similar entities: ['Romanian Academy', 'Royal Geographical Society', 'Tsinghua University', 'Harvard University', 'University of Oslo']
# Entity: Ivan the Terrible
# Similar entities: ['Catherine the Great', 'Ramesses II', 'Nikolai Rimsky-Korsakov', 'Cao Cao', 'Hirohito']
# Entity: Lionel Messi
# Similar entities: ['Wayne Gretzky', 'F.C. Bayern Munich', 'Tom Brady', 'Kevin Durant', 'Dwayne Johnson']
# Top 5 Accuracy: 0.1484375
# (0.8669438669438669, 0.1484375)

# %% [markdown]
# ## Follow up
# You may be surprised by the low accuracy on the top k task, but when you look at the output, you should see that the similar entities are reasonable. The dataset we are using wasn't designed to rank similar entities, rather only to do the binary  classification task. In this case our ground truth is quite noisy so the quantitative results may be misleading.

# %% [markdown]
# Once you're ready to submit, you can run the cell below to prepare and zip up your solution:

# %%
# %%bash
#
# if [[ ! -f "./pa4.ipynb" ]]
# then
#     echo "WARNING: Did not find notebook in Jupyter working directory. This probably means you're running on Google Colab. You'll need to go to File->Download .ipynb to download your notebok and other files, then zip them locally. See the README for more information."
# else
#     echo "Found notebook file, creating submission zip..."
#     zip -r submission.zip pa4.ipynb deps/
# fi
# Out:
# Found notebook file, creating submission zip...
# 	zip warning: name not matched: deps/
#   adding: pa4.ipynb (deflated 83%)

# %% [markdown]
# If you're running on Google Colab, see the README for instructions on how to submit.
#
# __Best of luck!__
#
# __Some reminders for submission:__
#  * Make sure you didn't accidentally change the name of your notebook file, (it should be `pa4.ipynb`) as that is required for the autograder to work.
# * Go to Gradescope (gradescope.com), find the PA4 Quizlet assignment and upload your zip file (`submission.zip`) as your solution.
# * Wait for the autograder to run and check that your submission was graded successfully! If the autograder fails, or you get an unexpected score it may be a sign that your zip file was incorrect.
